# %%
import gym
import numpy as np
env = gym.make('Taxi-v3', render_mode="rgb_array")
env.reset()
# Out:
# (246, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})

# %%
# 6 primitive actions ["south,north,east,west,pick,drop"]
action = np.random.randint(0, 6)
next_state, reward, done, truncated, info = env.step(action)

# %%
env.spec
# Out:
# EnvSpec(id='Taxi-v3', entry_point='gym.envs.toy_text.taxi:TaxiEnv', reward_threshold=8, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={'render_mode': 'rgb_array'}, namespace=None, name='Taxi', version=3)

# %%
"Id: [0:Red,1:Green,2:Yellow,3:Blue,4:Taxi]"
taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(114)

# %%
import matplotlib.pyplot as plt

plt.imshow(env.render())
output_filename = 'output_image.png'
plt.savefig(output_filename, format='png')

# %% [markdown]
# # Epsilon Greedy Exploration

# %%
def epsilon_greedy(q_values, state, epsilon):
    if q_values[state].any() and np.random.random() > epsilon:
        return np.argmax(q_values[state])
    choice = np.random.randint(0, q_values.shape[-1]-1)
    return choice

# %%
def xy_to_state(x, y):
    return 5*x+y

# %% [markdown]
# # Defined Option

# %%
# 4 different q tables to maintain for each goal square
# goal  =[red,green,yellow,blue]
def Option(Q, state, square_colour, goal, eps=0.1):
    optdone = False
    taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(
        state)
    if taxi_row == goal[square_colour][0] and taxi_col == goal[square_colour][1]:
        optdone = True
        if passenger_location_id == square_colour:
            optact = 4
        elif drop_location_id == square_colour:
            optact = 5
        else:
            if square_colour == 0:
                optact = 0
            elif square_colour == 1:
                optact = 0
            elif square_colour == 2:
                optact = 1
            else:
                optact = 1
    else:
        optact = epsilon_greedy(Q[square_colour], xy_to_state(
            taxi_row, taxi_col), epsilon=eps)
    return [optact, optdone]

# %%
def get_grid_no_drop(pas, drop, nDrops=4):
    return nDrops*pas+drop

# %% [markdown]
# # Training Loop

# %%
from collections import deque
# yellow = [4,0]
# blue = [4,3]
# red  = [0,0]
# green = [0,4]
# goal  =[red,green,yellow,blue]
goals = {0: [0, 0], 1: [0, 4], 2: [4, 0], 3: [4, 3]}
gamma = 0.9
alpha = 0.1
number_options = 4
nPas = 5  # number of passengger locations
nDrops = 4  # number of drop locations
# 4 each different locations , i am learning best option for that
# q table for the 25 cells and 4 actions excluding the pick and drop, for all the options
Qopt = {i: np.zeros((25, 4))
        for i in range(number_options)}

Q_smdp = np.zeros((nPas*nDrops, number_options))
state_counts = np.zeros((25, nPas*nDrops))
epsilon = [0.1 for i in range(number_options)]
epsilon_min = 0.01
decay_factor = 0.99
episodes = 2000
count = 0
rewards_smdp = []
goal = {0: [0, 0], 1: [0, 4], 2: [4, 0], 3: [4, 3]}
eps_q = 0.2
score_history = deque(maxlen=100)
for i in range(episodes):
    state, _ = env.reset()
    done = False
    total_reward = 0
    while not done:
        taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(
            state)
        subState = get_grid_no_drop(passenger_location_id, drop_location_id)
        action = epsilon_greedy(Q_smdp, subState, epsilon=eps_q)
        eps_q = max(epsilon_min, eps_q*decay_factor)
        reward_bar = 0
        optdone = False
        k = 0
        prev = state
        while not optdone and not done:
            optact, optdone = Option(
                Qopt, state, action, goal, epsilon[action])

            taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(
                state)
            dropgridno_old = get_grid_no_drop(
                passenger_location_id, drop_location_id)
            next_state, reward, done, _, _ = env.step(optact)
            taxi_row_new, taxi_col_new, passenger_location_id, drop_location_id = env.decode(
                next_state)
            total_reward += reward
            reward_bar = gamma*reward_bar + reward
            k += 1
            epsilon[action] = max(
                epsilon_min, epsilon[action]*decay_factor)
            reward_surr = reward
            if optact < 4:

                Qopt[action][xy_to_state(taxi_row, taxi_col), optact] = Qopt[action][xy_to_state(taxi_row, taxi_col), optact]+alpha*(
                    reward_surr+gamma*np.max(Qopt[action][xy_to_state(taxi_row_new, taxi_col_new), :])-Qopt[action][xy_to_state(taxi_row, taxi_col), optact])
            state = next_state

            state_counts[5*taxi_row_new+taxi_col_new, dropgridno_old] += 1
        taxi_row_new, taxi_col_new, passenger_location_id, drop_location_id = env.decode(
            state)
        dropgridno_new = get_grid_no_drop(
            passenger_location_id, drop_location_id)
        taxi_row_prev, taxi_col_prev, passenger_location_id, drop_location_id = env.decode(
            state)
        dropgridno_old = get_grid_no_drop(
            passenger_location_id, drop_location_id)
        taxi_row_new, taxi_col_new, passenger_location_id, drop_location_id = env.decode(
            state)
        # this is where the smdp update is done
        # state_counts[5*taxi_row_prev+taxi_col_prev, dropgridno_old] += 1
        Q_smdp[dropgridno_old, action] += alpha*(reward_bar+(gamma**k)*np.max(
            Q_smdp[dropgridno_new, :])-Q_smdp[dropgridno_old, action])
        taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(
            state)

        if passenger_location_id == drop_location_id:
            count += 1
    rewards_smdp.append(total_reward)
    score_history.append(total_reward)
    if (i+1) % 100 == 0:
        print(f"Episode {i+1} : Average Reward = {np.mean(score_history)}")
    if np.mean(score_history) >= 8:
        print(
            f"Environment solved in {i+1} epsiodes Average Reward:{np.mean(score_history)}")
        break
# Out:
# Episode 100 : Average Reward = -106.36
# Episode 200 : Average Reward = -14.81
# Episode 300 : Average Reward = -2.85
# Episode 400 : Average Reward = 0.28
# Episode 500 : Average Reward = 4.16
# Episode 600 : Average Reward = 5.64
# Episode 700 : Average Reward = 5.84
# Episode 800 : Average Reward = 5.95
# Episode 900 : Average Reward = 6.83
# Episode 1000 : Average Reward = 6.86
# Episode 1100 : Average Reward = 6.58
# Episode 1200 : Average Reward = 6.95
# Episode 1300 : Average Reward = 7.53
# Episode 1400 : Average Reward = 7.21
# Episode 1500 : Average Reward = 7.46
# Episode 1600 : Average Reward = 7.29
# Episode 1700 : Average Reward = 7.28
# Episode 1800 : Average Reward = 7.4
# Episode 1900 : Average Reward = 7.67
# Environment solved in 1924 epsiodes Average Reward:8.0

# %%
import matplotlib.pyplot as plt
window = 100
avg_rews_smdp = [np.average(rewards_smdp[i:i+window])
                 for i in range(len(rewards_smdp)-window)]
plt.plot(avg_rews_smdp, label='Model Score')
plt.xlabel('Episodes')
plt.ylabel('score averaged over previous 100 runs')
plt.title('SMDP over options with Q-learning Option policies')
plt.legend()
plt.axhline(y=8, color='red', linestyle='--')

# %% [markdown]
# # Testing the Learnt Policy

# %%
env = gym.make("Taxi-v3", render_mode="human")
state, _ = env.reset()
done = False
q_values_SMDP = Q_smdp
net_reward = 0
x, y, pas, drop = env.decode(state)
subState = nDrops*pas+drop
print(f"Runnning the training for substate={subState}")
while not done:
    x, y, pas, drop = env.decode(state)
    subState = nDrops*pas+drop
    option = epsilon_greedy(q_values_SMDP, subState, epsilon=0)
    optdone = False
    move = 0
    prev = state
    while (optdone == False) and not done:
        x, y, pas, drop = env.decode(state)
        optdone = False
        while not optdone and not done:
            optact, optdone = Option(Qopt, state, option, goal, 0)
            next_state, reward, done, _, _ = env.step(optact)
            net_reward += reward
            env.render()
            state = next_state
print(f"Net reward for this substate = {net_reward}")
# Out:
# Runnning the training for substate=8
# Net reward for this substate = 12

# %%
import seaborn as sns
state_array = np.array(state_counts, dtype="int")
num_substates = 20
fig, axes = plt.subplots(4, 5, figsize=(15, 12))

for substate in range(num_substates):
    substate_counts_1d = state_array[:, substate]
    substate_counts_2d = substate_counts_1d.reshape((5, 5))

    ax = axes[substate // 5, substate % 5]

    sns.heatmap(substate_counts_2d, annot=True,
                cmap='coolwarm', fmt='d', ax=ax)

    ax.set_title(
        f'(Passenger,Drop location)= {substate//nDrops,substate%nDrops}')

    ax.set_xlabel('Column')
    ax.set_ylabel('Row')

fig.suptitle('State Counts Heatmaps for Each Substate', fontsize=16)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

Qmax_SMDP = np.argmax(q_values_SMDP, axis=1).reshape(5, 4)
labels = {0: 'Red', 1: 'Green', 2: 'Yellow', 3: 'Blue'}
annot_text = np.vectorize(labels.get)(Qmax_SMDP)
figure, axis = plt.subplots(1, 1, figsize=(10, 10))
ax = sns.heatmap(Qmax_SMDP, ax=axis, xticklabels=["R", "G", "Y", "B"], yticklabels=[
                 'R', 'G', 'Y', 'B', 'Taxi'], annot=annot_text, fmt='')
c_bar = ax.collections[0].colorbar
c_bar.set_ticks([0, 1, 2, 3])
c_bar.set_ticklabels(['Red', 'Green', 'Yellow', 'Blue'])
axis.set_xlabel('Drop off points')
axis.set_ylabel("Passenger location")
axis.set_title('Policy learnt by SMDP')
# Out:
# Text(0.5, 1.0, 'Policy learnt by SMDP')

# %%
figure, axis = plt.subplots(2, 2, figsize=(13, 13))
goal_labels = ['Red', 'Green', 'Yellow', 'Blue']
for i in range(2):
    for j in range(2):
        arrows = {0: '↓', 1: '↑', 2: '→', 3: '←'}
        annot_text = np.vectorize(arrows.get)(
            np.argmax(Qopt[2*i+j], axis=1).reshape(5, 5))
        ax = sns.heatmap(np.argmax(
            Qopt[2*i+j], axis=1).reshape(5, 5), ax=axis[i, j], annot=annot_text, fmt='')
        axis[i, j].set_title(
            "Policy learnt (Fully learnt SMDP)) Goal Location={} tile".format(goal_labels[i*2+j]))
        c_bar = ax.collections[0].colorbar
        c_bar.set_ticks([i for i in range(4)])
        c_bar.set_ticklabels(['south', 'north', 'east', 'west'])
plt.show()

# %% [markdown]
# # Alternative Option test

# %%
from collections import deque
from tqdm import tqdm
import matplotlib.pyplot as plt

env = gym.make("Taxi-v3")
state, _ = env.reset()

number_drops = 0
gamma = 0.9
alpha = 0.1
number_options = 4
nPas = 5  # number of passengger locations
nDrops = 4  # number of drop locations

Q_smdp = np.zeros((25, nPas*nDrops, number_options))

state_counts = np.zeros((25, nPas*nDrops))
epsilon_min = 0.01
decay_factor = 0.9
episodes = 3500
count = 0
rewards_smdp = []
# goal = {'top_x': 0, 'left_y': 0, 'bottom_x': 4, 'right_y': 4}
# action 0, 1 2 3  N S E W
eps_q = 0.1
score_history = deque(maxlen=100)
number_drops = 0
for i in range(episodes):
    state, _ = env.reset()
    done = False
    total_reward = 0
    truncated = False
    in_taxi = False
    action_counts = [0, 0, 0, 0]
    steps = 0
    while not done and not truncated:
        taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(
            state)
        subState = get_grid_no_drop(passenger_location_id, drop_location_id)
        action = epsilon_greedy(
            Q_smdp[5*taxi_row+taxi_col], subState, epsilon=eps_q)
        eps_q = max(epsilon_min, eps_q*decay_factor)
        reward_bar = 0
        optdone = False
        k = 0
        prev = [taxi_row, taxi_col]
        state_counts[5*taxi_row+taxi_col, subState] += 1
        if not optdone and not done:
            optact = action
            for j in range(2):
                taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(
                    state)
                next_state, reward, done, truncated, _ = env.step(optact)
                steps += 1
                taxi_row_new, taxi_col_new, passenger_location_id, drop_location_id = env.decode(
                    next_state)
                state_counts[5*taxi_row_new+taxi_col_new, subState] += 1
                total_reward += reward
                reward_bar = gamma*reward_bar + reward
                k += 1
                reward_surr = reward

                taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(
                    next_state)
                locations = {0: [0, 0], 1: [0, 4], 2: [4, 0],
                             3: [4, 3], 4: [taxi_row, taxi_col]}
                loc = locations[passenger_location_id]
                if loc[0] == taxi_row and loc[1] == taxi_col and drop_location_id != passenger_location_id and not in_taxi:
                    optact = 4
                    in_taxi = True
                    optdone = True
                    next_state, reward, done, truncated, _ = env.step(optact)
                    break

                if goal[drop_location_id][0] == taxi_row and goal[drop_location_id][1] == taxi_col and passenger_location_id == 4 and in_taxi:
                    optact = 5
                    optdone = True
                    number_drops += 1
                    next_state, reward, done, truncated, _ = env.step(optact)
                    break

                state = next_state

            optdone = True

        dropgridno = get_grid_no_drop(
            passenger_location_id, drop_location_id)
        taxi_row_new, taxi_col_new, passenger_location_id, drop_location_id = env.decode(
            state)
        Q_smdp[prev[0]*5+prev[1], dropgridno, action] += alpha*(reward_bar+(gamma**k)*np.max(
            Q_smdp[taxi_row_new*5+taxi_col_new, dropgridno])-Q_smdp[prev[0]*5+prev[1], dropgridno, action])

    rewards_smdp.append(total_reward)
    score_history.append(total_reward)
    if (i+1) % 1 == 0:
        print(
            f"Episode {i+1} : Average Reward = {np.mean(score_history)}  Number_drops:{number_drops} steps:{steps}")
# Out:
# Episode 1 : Average Reward = -164.0  Number_drops:1 steps:164
# Episode 2 : Average Reward = -154.5  Number_drops:2 steps:145
# Episode 3 : Average Reward = -149.66666666666666  Number_drops:3 steps:140
# Episode 4 : Average Reward = -160.5  Number_drops:4 steps:193
# Episode 5 : Average Reward = -164.4  Number_drops:5 steps:180
# Episode 6 : Average Reward = -156.33333333333334  Number_drops:6 steps:116
# Episode 7 : Average Reward = -159.42857142857142  Number_drops:7 steps:178
# Episode 8 : Average Reward = -157.75  Number_drops:8 steps:146
# Episode 9 : Average Reward = -151.33333333333334  Number_drops:9 steps:100
# Episode 10 : Average Reward = -156.1  Number_drops:9 steps:199
# Episode 11 : Average Reward = -158.1818181818182  Number_drops:10 steps:179
# Episode 12 : Average Reward = -152.91666666666666  Number_drops:11 steps:95
# Episode 13 : Average Reward = -146.46153846153845  Number_drops:12 steps:69
# Episode 14 : Average Reward = -144.71428571428572  Number_drops:13 steps:122
# Episode 15 : Average Reward = -148.4  Number_drops:13 steps:200
# Episode 16 : Average Reward = -146.6875  Number_drops:14 steps:121
# Episode 17 : Average Reward = -148.35294117647058  Number_drops:15 steps:175
# Episode 18 : Average Reward = -142.72222222222223  Number_drops:16 steps:47
# Episode 19 : Average Reward = -140.68421052631578  Number_drops:17 steps:104
# Episode 20 : Average Reward = -140.8  Number_drops:18 steps:143
# Episode 21 : Average Reward = -137.61904761904762  Number_drops:19 steps:74
# Episode 22 : Average Reward = -140.45454545454547  Number_drops:19 steps:200
# Episode 23 : Average Reward = -140.30434782608697  Number_drops:20 steps:137
# Episode 24 : Average Reward = -137.125  Number_drops:21 steps:64
# Episode 25 : Average Reward = -134.84  Number_drops:22 steps:80
# Episode 26 : Average Reward = -133.80769230769232  Number_drops:23 steps:108
# Episode 27 : Average Reward = -131.66666666666666  Number_drops:24 steps:76
# Episode 28 : Average Reward = -131.25  Number_drops:25 steps:120
# Episode 29 : Average Reward = -133.6206896551724  Number_drops:25 steps:200
# Episode 30 : Average Reward = -132.06666666666666  Number_drops:26 steps:87
# Episode 31 : Average Reward = -132.67741935483872  Number_drops:27 steps:151
# Episode 32 : Average Reward = -132.84375  Number_drops:28 steps:138
# Episode 33 : Average Reward = -132.63636363636363  Number_drops:29 steps:126
# Episode 34 : Average Reward = -132.7941176470588  Number_drops:30 steps:138
# Episode 35 : Average Reward = -134.71428571428572  Number_drops:30 steps:200
# Episode 36 : Average Reward = -134.47222222222223  Number_drops:31 steps:126
# Episode 37 : Average Reward = -133.1891891891892  Number_drops:32 steps:87
# Episode 38 : Average Reward = -131.3421052631579  Number_drops:33 steps:63
# Episode 39 : Average Reward = -129.66666666666666  Number_drops:34 steps:66
# Episode 40 : Average Reward = -127.1  Number_drops:35 steps:27
# Episode 41 : Average Reward = -127.04878048780488  Number_drops:36 steps:125
# Episode 42 : Average Reward = -126.69047619047619  Number_drops:37 steps:112
# Episode 43 : Average Reward = -126.23255813953489  Number_drops:38 steps:107
# Episode 44 : Average Reward = -127.81818181818181  Number_drops:39 steps:196
# Episode 45 : Average Reward = -128.0  Number_drops:40 steps:136
# Episode 46 : Average Reward = -127.80434782608695  Number_drops:41 steps:119
# Episode 47 : Average Reward = -129.3404255319149  Number_drops:41 steps:200
# Episode 48 : Average Reward = -128.8125  Number_drops:42 steps:104
# Episode 49 : Average Reward = -129.59183673469389  Number_drops:43 steps:167
# Episode 50 : Average Reward = -129.0  Number_drops:44 steps:100
# Episode 51 : Average Reward = -127.86274509803921  Number_drops:45 steps:71
# Episode 52 : Average Reward = -129.17307692307693  Number_drops:46 steps:196
# Episode 53 : Average Reward = -130.50943396226415  Number_drops:46 steps:200
# Episode 54 : Average Reward = -131.7962962962963  Number_drops:46 steps:200
# Episode 55 : Average Reward = -129.94545454545454  Number_drops:47 steps:30
# Episode 56 : Average Reward = -130.33928571428572  Number_drops:48 steps:152
# Episode 57 : Average Reward = -129.31578947368422  Number_drops:49 steps:72
# Episode 58 : Average Reward = -128.98275862068965  Number_drops:50 steps:110
# Episode 59 : Average Reward = -130.16949152542372  Number_drops:50 steps:199
# Episode 60 : Average Reward = -130.05  Number_drops:51 steps:123
# Episode 61 : Average Reward = -129.63934426229508  Number_drops:52 steps:105
# Episode 62 : Average Reward = -129.0  Number_drops:53 steps:90
# Episode 63 : Average Reward = -128.12698412698413  Number_drops:54 steps:74
# Episode 64 : Average Reward = -127.546875  Number_drops:55 steps:91
# Episode 65 : Average Reward = -127.47692307692307  Number_drops:56 steps:123
# Episode 66 : Average Reward = -126.07575757575758  Number_drops:57 steps:35
# Episode 67 : Average Reward = -126.7910447761194  Number_drops:58 steps:174
# Episode 68 : Average Reward = -127.54411764705883  Number_drops:59 steps:178
# Episode 69 : Average Reward = -126.73913043478261  Number_drops:60 steps:72
# Episode 70 : Average Reward = -126.37142857142857  Number_drops:61 steps:101
# Episode 71 : Average Reward = -125.11267605633803  Number_drops:62 steps:37
# Episode 72 : Average Reward = -125.69444444444444  Number_drops:63 steps:167
# Episode 73 : Average Reward = -125.52054794520548  Number_drops:64 steps:113
# Episode 74 : Average Reward = -126.52702702702703  Number_drops:64 steps:200
# Episode 75 : Average Reward = -126.4  Number_drops:65 steps:117
# Episode 76 : Average Reward = -127.15789473684211  Number_drops:66 steps:184
# Episode 77 : Average Reward = -126.31168831168831  Number_drops:67 steps:62
# Episode 78 : Average Reward = -125.21794871794872  Number_drops:68 steps:41
# Episode 79 : Average Reward = -124.89873417721519  Number_drops:69 steps:100
# Episode 80 : Average Reward = -125.775  Number_drops:70 steps:195
# Episode 81 : Average Reward = -126.12345679012346  Number_drops:71 steps:154
# Episode 82 : Average Reward = -126.03658536585365  Number_drops:72 steps:119
# Episode 83 : Average Reward = -126.75903614457832  Number_drops:73 steps:186
# Episode 84 : Average Reward = -125.58333333333333  Number_drops:74 steps:28
# Episode 85 : Average Reward = -124.54117647058824  Number_drops:75 steps:37
# Episode 86 : Average Reward = -123.94186046511628  Number_drops:76 steps:73
# Episode 87 : Average Reward = -123.62068965517241  Number_drops:77 steps:96
# Episode 88 : Average Reward = -124.48863636363636  Number_drops:77 steps:200
# Episode 89 : Average Reward = -123.80898876404494  Number_drops:78 steps:64
# Episode 90 : Average Reward = -122.9888888888889  Number_drops:79 steps:50
# Episode 91 : Average Reward = -122.17582417582418  Number_drops:80 steps:49
# Episode 92 : Average Reward = -121.71739130434783  Number_drops:81 steps:80
# Episode 93 : Average Reward = -121.76344086021506  Number_drops:82 steps:126
# Episode 94 : Average Reward = -121.09574468085107  Number_drops:83 steps:59
# Episode 95 : Average Reward = -121.8  Number_drops:84 steps:188
# Episode 96 : Average Reward = -120.875  Number_drops:85 steps:33
# Episode 97 : Average Reward = -121.69072164948453  Number_drops:85 steps:200
# Episode 98 : Average Reward = -120.6938775510204  Number_drops:86 steps:24
# Episode 99 : Average Reward = -121.4949494949495  Number_drops:86 steps:200
# Episode 100 : Average Reward = -120.52  Number_drops:87 steps:24
# Episode 101 : Average Reward = -119.5  Number_drops:88 steps:62
# Episode 102 : Average Reward = -118.95  Number_drops:89 steps:90
# Episode 103 : Average Reward = -118.21  Number_drops:90 steps:66
# Episode 104 : Average Reward = -117.58  Number_drops:91 steps:130
# Episode 105 : Average Reward = -116.53  Number_drops:92 steps:75
# Episode 106 : Average Reward = -116.25  Number_drops:93 steps:88
# Episode 107 : Average Reward = -116.04  Number_drops:94 steps:157
# Episode 108 : Average Reward = -115.1  Number_drops:95 steps:52
# Episode 109 : Average Reward = -114.89  Number_drops:96 steps:79
# Episode 110 : Average Reward = -113.83  Number_drops:97 steps:93
# Episode 111 : Average Reward = -112.31  Number_drops:98 steps:27
# Episode 112 : Average Reward = -113.27  Number_drops:99 steps:191
# Episode 113 : Average Reward = -113.83  Number_drops:100 steps:125
# Episode 114 : Average Reward = -113.71  Number_drops:101 steps:110
# Episode 115 : Average Reward = -112.99  Number_drops:102 steps:128
# Episode 116 : Average Reward = -112.72  Number_drops:103 steps:94
# Episode 117 : Average Reward = -111.95  Number_drops:104 steps:98
# Episode 118 : Average Reward = -112.75  Number_drops:105 steps:127
# Episode 119 : Average Reward = -112.77  Number_drops:106 steps:106
# Episode 120 : Average Reward = -111.97  Number_drops:107 steps:63
# Episode 121 : Average Reward = -112.24  Number_drops:108 steps:101
# Episode 122 : Average Reward = -112.24  Number_drops:108 steps:200
# Episode 123 : Average Reward = -112.21  Number_drops:109 steps:134
# Episode 124 : Average Reward = -112.63  Number_drops:110 steps:106
# Episode 125 : Average Reward = -112.48  Number_drops:111 steps:65
# Episode 126 : Average Reward = -111.95  Number_drops:112 steps:55
# Episode 127 : Average Reward = -112.39  Number_drops:113 steps:120
# Episode 128 : Average Reward = -111.67  Number_drops:114 steps:48
# Episode 129 : Average Reward = -110.34  Number_drops:115 steps:67
# Episode 130 : Average Reward = -110.33  Number_drops:116 steps:86
# Episode 131 : Average Reward = -110.67  Number_drops:117 steps:185
# Episode 132 : Average Reward = -110.55  Number_drops:118 steps:126
# Episode 133 : Average Reward = -109.69  Number_drops:119 steps:40
# Episode 134 : Average Reward = -109.04  Number_drops:120 steps:73
# Episode 135 : Average Reward = -108.03  Number_drops:121 steps:99
# Episode 136 : Average Reward = -107.68  Number_drops:122 steps:91
# Episode 137 : Average Reward = -107.79  Number_drops:123 steps:98
# Episode 138 : Average Reward = -108.54  Number_drops:124 steps:138
# Episode 139 : Average Reward = -108.8  Number_drops:125 steps:92
# Episode 140 : Average Reward = -109.07  Number_drops:126 steps:54
# Episode 141 : Average Reward = -109.1  Number_drops:127 steps:128
# Episode 142 : Average Reward = -108.87  Number_drops:128 steps:89
# Episode 143 : Average Reward = -108.26  Number_drops:129 steps:46
# Episode 144 : Average Reward = -106.92  Number_drops:130 steps:62
# Episode 145 : Average Reward = -105.76  Number_drops:131 steps:20
# Episode 146 : Average Reward = -105.43  Number_drops:132 steps:86
# Episode 147 : Average Reward = -104.17  Number_drops:133 steps:74
# Episode 148 : Average Reward = -104.32  Number_drops:134 steps:119
# Episode 149 : Average Reward = -103.75  Number_drops:135 steps:110
# Episode 150 : Average Reward = -103.15  Number_drops:136 steps:40
# Episode 151 : Average Reward = -103.89  Number_drops:137 steps:145
# Episode 152 : Average Reward = -102.63  Number_drops:138 steps:70
# Episode 153 : Average Reward = -101.68  Number_drops:139 steps:105
# Episode 154 : Average Reward = -99.99  Number_drops:140 steps:31
# Episode 155 : Average Reward = -100.38  Number_drops:141 steps:69
# Episode 156 : Average Reward = -99.42  Number_drops:142 steps:56
# Episode 157 : Average Reward = -99.76  Number_drops:143 steps:106
# Episode 158 : Average Reward = -99.3  Number_drops:144 steps:64
# Episode 159 : Average Reward = -98.67  Number_drops:145 steps:136
# Episode 160 : Average Reward = -99.44  Number_drops:145 steps:200
# Episode 161 : Average Reward = -98.62  Number_drops:146 steps:23
# Episode 162 : Average Reward = -98.99  Number_drops:147 steps:127
# Episode 163 : Average Reward = -98.79  Number_drops:148 steps:54
# Episode 164 : Average Reward = -99.38  Number_drops:149 steps:150
# Episode 165 : Average Reward = -98.35  Number_drops:150 steps:20
# Episode 166 : Average Reward = -98.55  Number_drops:151 steps:55
# Episode 167 : Average Reward = -97.86  Number_drops:152 steps:105
# Episode 168 : Average Reward = -96.94  Number_drops:153 steps:86
# Episode 169 : Average Reward = -96.68  Number_drops:154 steps:46
# Episode 170 : Average Reward = -96.39  Number_drops:155 steps:72
# Episode 171 : Average Reward = -96.66  Number_drops:156 steps:64
# Episode 172 : Average Reward = -96.32  Number_drops:157 steps:133
# Episode 173 : Average Reward = -95.56  Number_drops:158 steps:37
# Episode 174 : Average Reward = -94.63  Number_drops:159 steps:107
# Episode 175 : Average Reward = -94.34  Number_drops:160 steps:88
# Episode 176 : Average Reward = -92.82  Number_drops:161 steps:32
# Episode 177 : Average Reward = -92.55  Number_drops:162 steps:35
# Episode 178 : Average Reward = -93.14  Number_drops:163 steps:100
# Episode 179 : Average Reward = -93.36  Number_drops:164 steps:122
# Episode 180 : Average Reward = -91.78  Number_drops:165 steps:37
# Episode 181 : Average Reward = -90.77  Number_drops:166 steps:53
# Episode 182 : Average Reward = -90.34  Number_drops:167 steps:76
# Episode 183 : Average Reward = -90.15  Number_drops:168 steps:167
# Episode 184 : Average Reward = -91.38  Number_drops:169 steps:151
# Episode 185 : Average Reward = -91.73  Number_drops:170 steps:72
# Episode 186 : Average Reward = -91.58  Number_drops:171 steps:58
# Episode 187 : Average Reward = -91.5  Number_drops:172 steps:88
# Episode 188 : Average Reward = -89.62  Number_drops:173 steps:12
# Episode 189 : Average Reward = -89.33  Number_drops:174 steps:35
# Episode 190 : Average Reward = -89.8  Number_drops:175 steps:97
# Episode 191 : Average Reward = -90.21  Number_drops:176 steps:90
# Episode 192 : Average Reward = -89.78  Number_drops:177 steps:37
# Episode 193 : Average Reward = -89.21  Number_drops:178 steps:69
# Episode 194 : Average Reward = -90.22  Number_drops:179 steps:160
# Episode 195 : Average Reward = -88.55  Number_drops:180 steps:21
# Episode 196 : Average Reward = -88.83  Number_drops:181 steps:61
# Episode 197 : Average Reward = -87.6  Number_drops:182 steps:77
# Episode 198 : Average Reward = -88.55  Number_drops:183 steps:119
# Episode 199 : Average Reward = -87.17  Number_drops:184 steps:62
# Episode 200 : Average Reward = -87.73  Number_drops:185 steps:80
# Episode 201 : Average Reward = -87.57  Number_drops:186 steps:46
# Episode 202 : Average Reward = -88.04  Number_drops:187 steps:137
# Episode 203 : Average Reward = -88.16  Number_drops:188 steps:78
# Episode 204 : Average Reward = -87.2  Number_drops:189 steps:34
# Episode 205 : Average Reward = -88.16  Number_drops:190 steps:171
# Episode 206 : Average Reward = -87.4  Number_drops:191 steps:12
# Episode 207 : Average Reward = -86.43  Number_drops:192 steps:60
# Episode 208 : Average Reward = -86.35  Number_drops:193 steps:44
# Episode 209 : Average Reward = -86.02  Number_drops:194 steps:46
# Episode 210 : Average Reward = -85.68  Number_drops:195 steps:59
# Episode 211 : Average Reward = -87.2  Number_drops:196 steps:179
# Episode 212 : Average Reward = -86.43  Number_drops:197 steps:114
# Episode 213 : Average Reward = -86.03  Number_drops:198 steps:85
# Episode 214 : Average Reward = -85.69  Number_drops:199 steps:76
# Episode 215 : Average Reward = -86.0  Number_drops:200 steps:159
# Episode 216 : Average Reward = -85.53  Number_drops:201 steps:47
# Episode 217 : Average Reward = -85.04  Number_drops:202 steps:49
# Episode 218 : Average Reward = -84.43  Number_drops:203 steps:66
# Episode 219 : Average Reward = -84.05  Number_drops:204 steps:68
# Episode 220 : Average Reward = -83.8  Number_drops:205 steps:38
# Episode 221 : Average Reward = -83.21  Number_drops:206 steps:42
# Episode 222 : Average Reward = -81.54  Number_drops:207 steps:33
# Episode 223 : Average Reward = -80.44  Number_drops:208 steps:24
# Episode 224 : Average Reward = -80.19  Number_drops:209 steps:81
# Episode 225 : Average Reward = -79.9  Number_drops:210 steps:36
# Episode 226 : Average Reward = -80.39  Number_drops:211 steps:104
# Episode 227 : Average Reward = -80.51  Number_drops:212 steps:132
# Episode 228 : Average Reward = -80.24  Number_drops:213 steps:21
# Episode 229 : Average Reward = -80.44  Number_drops:214 steps:87
# Episode 230 : Average Reward = -80.02  Number_drops:215 steps:44
# Episode 231 : Average Reward = -79.09  Number_drops:216 steps:92
# Episode 232 : Average Reward = -78.27  Number_drops:217 steps:44
# Episode 233 : Average Reward = -78.06  Number_drops:218 steps:19
# Episode 234 : Average Reward = -77.73  Number_drops:219 steps:40
# Episode 235 : Average Reward = -76.79  Number_drops:220 steps:5
# Episode 236 : Average Reward = -76.4  Number_drops:221 steps:52
# Episode 237 : Average Reward = -76.45  Number_drops:222 steps:103
# Episode 238 : Average Reward = -75.31  Number_drops:223 steps:24
# Episode 239 : Average Reward = -75.11  Number_drops:224 steps:72
# Episode 240 : Average Reward = -75.9  Number_drops:225 steps:133
# Episode 241 : Average Reward = -75.36  Number_drops:226 steps:74
# Episode 242 : Average Reward = -75.19  Number_drops:227 steps:72
# Episode 243 : Average Reward = -76.14  Number_drops:228 steps:141
# Episode 244 : Average Reward = -75.75  Number_drops:229 steps:23
# Episode 245 : Average Reward = -76.07  Number_drops:230 steps:52
# Episode 246 : Average Reward = -75.54  Number_drops:231 steps:33
# Episode 247 : Average Reward = -76.0  Number_drops:232 steps:120
# Episode 248 : Average Reward = -75.91  Number_drops:233 steps:110
# Episode 249 : Average Reward = -74.98  Number_drops:234 steps:17
# Episode 250 : Average Reward = -75.68  Number_drops:235 steps:110
# Episode 251 : Average Reward = -74.8  Number_drops:236 steps:57
# Episode 252 : Average Reward = -74.99  Number_drops:237 steps:89
# Episode 253 : Average Reward = -74.96  Number_drops:238 steps:102
# Episode 254 : Average Reward = -76.5  Number_drops:239 steps:185
# Episode 255 : Average Reward = -76.98  Number_drops:240 steps:117
# Episode 256 : Average Reward = -76.78  Number_drops:241 steps:36
# Episode 257 : Average Reward = -76.81  Number_drops:242 steps:109
# Episode 258 : Average Reward = -76.57  Number_drops:243 steps:40
# Episode 259 : Average Reward = -75.95  Number_drops:244 steps:74
# Episode 260 : Average Reward = -74.4  Number_drops:245 steps:45
# Episode 261 : Average Reward = -74.57  Number_drops:246 steps:40
# Episode 262 : Average Reward = -73.66  Number_drops:247 steps:36
# Episode 263 : Average Reward = -74.38  Number_drops:248 steps:126
# Episode 264 : Average Reward = -73.45  Number_drops:249 steps:57
# Episode 265 : Average Reward = -74.08  Number_drops:250 steps:83
# Episode 266 : Average Reward = -74.43  Number_drops:251 steps:90
# Episode 267 : Average Reward = -74.43  Number_drops:252 steps:105
# Episode 268 : Average Reward = -74.19  Number_drops:253 steps:62
# Episode 269 : Average Reward = -74.47  Number_drops:254 steps:74
# Episode 270 : Average Reward = -74.02  Number_drops:255 steps:27
# Episode 271 : Average Reward = -74.67  Number_drops:256 steps:129
# Episode 272 : Average Reward = -73.86  Number_drops:257 steps:52
# Episode 273 : Average Reward = -73.99  Number_drops:258 steps:50
# Episode 274 : Average Reward = -73.4  Number_drops:259 steps:48
# Episode 275 : Average Reward = -73.48  Number_drops:260 steps:96
# Episode 276 : Average Reward = -73.67  Number_drops:261 steps:51
# Episode 277 : Average Reward = -73.68  Number_drops:262 steps:36
# Episode 278 : Average Reward = -73.67  Number_drops:263 steps:99
# Episode 279 : Average Reward = -73.28  Number_drops:264 steps:83
# Episode 280 : Average Reward = -73.95  Number_drops:265 steps:104
# Episode 281 : Average Reward = -74.88  Number_drops:266 steps:146
# Episode 282 : Average Reward = -74.42  Number_drops:267 steps:30
# Episode 283 : Average Reward = -73.36  Number_drops:268 steps:61
# Episode 284 : Average Reward = -71.98  Number_drops:269 steps:13
# Episode 285 : Average Reward = -72.22  Number_drops:270 steps:96
# Episode 286 : Average Reward = -71.78  Number_drops:271 steps:14
# Episode 287 : Average Reward = -71.4  Number_drops:272 steps:50
# Episode 288 : Average Reward = -71.89  Number_drops:273 steps:61
# Episode 289 : Average Reward = -71.81  Number_drops:274 steps:27
# Episode 290 : Average Reward = -71.12  Number_drops:275 steps:28
# Episode 291 : Average Reward = -70.92  Number_drops:276 steps:70
# Episode 292 : Average Reward = -71.84  Number_drops:277 steps:129
# Episode 293 : Average Reward = -71.89  Number_drops:278 steps:74
# Episode 294 : Average Reward = -71.03  Number_drops:279 steps:74
# Episode 295 : Average Reward = -70.94  Number_drops:280 steps:12
# Episode 296 : Average Reward = -71.19  Number_drops:281 steps:86
# Episode 297 : Average Reward = -71.48  Number_drops:282 steps:106
# Episode 298 : Average Reward = -70.73  Number_drops:283 steps:44
# Episode 299 : Average Reward = -70.53  Number_drops:284 steps:42
# Episode 300 : Average Reward = -70.81  Number_drops:285 steps:108
# Episode 301 : Average Reward = -70.62  Number_drops:286 steps:27
# Episode 302 : Average Reward = -69.78  Number_drops:287 steps:53
# Episode 303 : Average Reward = -69.3  Number_drops:288 steps:30
# Episode 304 : Average Reward = -69.86  Number_drops:289 steps:90
# Episode 305 : Average Reward = -69.16  Number_drops:290 steps:101
# Episode 306 : Average Reward = -69.7  Number_drops:291 steps:66
# Episode 307 : Average Reward = -69.23  Number_drops:292 steps:13
# Episode 308 : Average Reward = -69.15  Number_drops:293 steps:36
# Episode 309 : Average Reward = -69.15  Number_drops:294 steps:46
# Episode 310 : Average Reward = -68.79  Number_drops:295 steps:23
# Episode 311 : Average Reward = -67.25  Number_drops:296 steps:25
# Episode 312 : Average Reward = -66.37  Number_drops:297 steps:26
# Episode 313 : Average Reward = -65.95  Number_drops:298 steps:43
# Episode 314 : Average Reward = -66.13  Number_drops:299 steps:94
# Episode 315 : Average Reward = -64.89  Number_drops:300 steps:35
# Episode 316 : Average Reward = -64.66  Number_drops:301 steps:24
# Episode 317 : Average Reward = -64.86  Number_drops:302 steps:69
# Episode 318 : Average Reward = -64.52  Number_drops:303 steps:32
# Episode 319 : Average Reward = -64.48  Number_drops:304 steps:64
# Episode 320 : Average Reward = -65.14  Number_drops:305 steps:104
# Episode 321 : Average Reward = -65.22  Number_drops:306 steps:50
# Episode 322 : Average Reward = -65.77  Number_drops:307 steps:88
# Episode 323 : Average Reward = -67.16  Number_drops:308 steps:163
# Episode 324 : Average Reward = -66.7  Number_drops:309 steps:35
# Episode 325 : Average Reward = -66.56  Number_drops:310 steps:22
# Episode 326 : Average Reward = -66.02  Number_drops:311 steps:50
# Episode 327 : Average Reward = -65.13  Number_drops:312 steps:43
# Episode 328 : Average Reward = -65.03  Number_drops:313 steps:11
# Episode 329 : Average Reward = -64.71  Number_drops:314 steps:55
# Episode 330 : Average Reward = -64.98  Number_drops:315 steps:71
# Episode 331 : Average Reward = -64.17  Number_drops:316 steps:11
# Episode 332 : Average Reward = -64.15  Number_drops:317 steps:42
# Episode 333 : Average Reward = -64.65  Number_drops:318 steps:69
# Episode 334 : Average Reward = -64.8  Number_drops:319 steps:55
# Episode 335 : Average Reward = -65.8  Number_drops:320 steps:105
# Episode 336 : Average Reward = -65.58  Number_drops:321 steps:30
# Episode 337 : Average Reward = -64.82  Number_drops:322 steps:27
# Episode 338 : Average Reward = -65.31  Number_drops:323 steps:73
# Episode 339 : Average Reward = -64.76  Number_drops:324 steps:17
# Episode 340 : Average Reward = -63.71  Number_drops:325 steps:28
# Episode 341 : Average Reward = -63.09  Number_drops:326 steps:12
# Episode 342 : Average Reward = -63.39  Number_drops:327 steps:102
# Episode 343 : Average Reward = -62.38  Number_drops:328 steps:40
# Episode 344 : Average Reward = -63.02  Number_drops:329 steps:87
# Episode 345 : Average Reward = -63.42  Number_drops:330 steps:92
# Episode 346 : Average Reward = -64.07  Number_drops:331 steps:98
# Episode 347 : Average Reward = -63.37  Number_drops:332 steps:50
# Episode 348 : Average Reward = -62.71  Number_drops:333 steps:44
# Episode 349 : Average Reward = -63.16  Number_drops:334 steps:62
# Episode 350 : Average Reward = -62.97  Number_drops:335 steps:91
# Episode 351 : Average Reward = -62.84  Number_drops:336 steps:44
# Episode 352 : Average Reward = -62.75  Number_drops:337 steps:80
# Episode 353 : Average Reward = -62.59  Number_drops:338 steps:86
# Episode 354 : Average Reward = -61.5  Number_drops:339 steps:76
# Episode 355 : Average Reward = -60.61  Number_drops:340 steps:28
# Episode 356 : Average Reward = -61.11  Number_drops:341 steps:86
# Episode 357 : Average Reward = -60.65  Number_drops:342 steps:63
# Episode 358 : Average Reward = -60.39  Number_drops:343 steps:14
# Episode 359 : Average Reward = -59.98  Number_drops:344 steps:33
# Episode 360 : Average Reward = -60.48  Number_drops:345 steps:95
# Episode 361 : Average Reward = -60.48  Number_drops:346 steps:40
# Episode 362 : Average Reward = -60.94  Number_drops:347 steps:82
# Episode 363 : Average Reward = -59.78  Number_drops:348 steps:10
# Episode 364 : Average Reward = -59.78  Number_drops:349 steps:57
# Episode 365 : Average Reward = -59.67  Number_drops:350 steps:72
# Episode 366 : Average Reward = -59.14  Number_drops:351 steps:37
# Episode 367 : Average Reward = -58.34  Number_drops:352 steps:25
# Episode 368 : Average Reward = -58.31  Number_drops:353 steps:59
# Episode 369 : Average Reward = -58.33  Number_drops:354 steps:76
# Episode 370 : Average Reward = -58.4  Number_drops:355 steps:34
# Episode 371 : Average Reward = -57.25  Number_drops:356 steps:14
# Episode 372 : Average Reward = -57.76  Number_drops:357 steps:103
# Episode 373 : Average Reward = -57.76  Number_drops:358 steps:50
# Episode 374 : Average Reward = -57.58  Number_drops:359 steps:30
# Episode 375 : Average Reward = -57.1  Number_drops:360 steps:48
# Episode 376 : Average Reward = -57.23  Number_drops:361 steps:64
# Episode 377 : Average Reward = -57.25  Number_drops:362 steps:38
# Episode 378 : Average Reward = -57.0  Number_drops:363 steps:74
# Episode 379 : Average Reward = -56.77  Number_drops:364 steps:60
# Episode 380 : Average Reward = -56.41  Number_drops:365 steps:68
# Episode 381 : Average Reward = -55.18  Number_drops:366 steps:23
# Episode 382 : Average Reward = -55.98  Number_drops:367 steps:110
# Episode 383 : Average Reward = -55.78  Number_drops:368 steps:41
# Episode 384 : Average Reward = -56.35  Number_drops:369 steps:70
# Episode 385 : Average Reward = -55.73  Number_drops:370 steps:34
# Episode 386 : Average Reward = -55.81  Number_drops:371 steps:22
# Episode 387 : Average Reward = -56.32  Number_drops:372 steps:101
# Episode 388 : Average Reward = -55.91  Number_drops:373 steps:20
# Episode 389 : Average Reward = -55.94  Number_drops:374 steps:30
# Episode 390 : Average Reward = -55.97  Number_drops:375 steps:31
# Episode 391 : Average Reward = -55.64  Number_drops:376 steps:37
# Episode 392 : Average Reward = -54.93  Number_drops:377 steps:58
# Episode 393 : Average Reward = -54.69  Number_drops:378 steps:50
# Episode 394 : Average Reward = -54.78  Number_drops:379 steps:83
# Episode 395 : Average Reward = -56.06  Number_drops:380 steps:140
# Episode 396 : Average Reward = -55.79  Number_drops:381 steps:59
# Episode 397 : Average Reward = -55.07  Number_drops:382 steps:34
# Episode 398 : Average Reward = -55.61  Number_drops:383 steps:98
# Episode 399 : Average Reward = -55.42  Number_drops:384 steps:23
# Episode 400 : Average Reward = -54.6  Number_drops:385 steps:26
# Episode 401 : Average Reward = -54.49  Number_drops:386 steps:16
# Episode 402 : Average Reward = -54.64  Number_drops:387 steps:68
# Episode 403 : Average Reward = -54.98  Number_drops:388 steps:64
# Episode 404 : Average Reward = -54.84  Number_drops:389 steps:76
# Episode 405 : Average Reward = -54.09  Number_drops:390 steps:26
# Episode 406 : Average Reward = -54.14  Number_drops:391 steps:71
# Episode 407 : Average Reward = -54.18  Number_drops:392 steps:17
# Episode 408 : Average Reward = -54.48  Number_drops:393 steps:66
# Episode 409 : Average Reward = -54.87  Number_drops:394 steps:85
# Episode 410 : Average Reward = -54.94  Number_drops:395 steps:30
# Episode 411 : Average Reward = -55.15  Number_drops:396 steps:46
# Episode 412 : Average Reward = -55.23  Number_drops:397 steps:34
# Episode 413 : Average Reward = -55.24  Number_drops:398 steps:44
# Episode 414 : Average Reward = -55.14  Number_drops:399 steps:84
# Episode 415 : Average Reward = -55.06  Number_drops:400 steps:27
# Episode 416 : Average Reward = -55.36  Number_drops:401 steps:54
# Episode 417 : Average Reward = -55.35  Number_drops:402 steps:68
# Episode 418 : Average Reward = -55.51  Number_drops:403 steps:48
# Episode 419 : Average Reward = -55.29  Number_drops:404 steps:42
# Episode 420 : Average Reward = -54.43  Number_drops:405 steps:18
# Episode 421 : Average Reward = -54.28  Number_drops:406 steps:35
# Episode 422 : Average Reward = -53.68  Number_drops:407 steps:28
# Episode 423 : Average Reward = -52.17  Number_drops:408 steps:12
# Episode 424 : Average Reward = -52.22  Number_drops:409 steps:40
# Episode 425 : Average Reward = -52.66  Number_drops:410 steps:66
# Episode 426 : Average Reward = -52.5  Number_drops:411 steps:34
# Episode 427 : Average Reward = -52.42  Number_drops:412 steps:35
# Episode 428 : Average Reward = -52.41  Number_drops:413 steps:10
# Episode 429 : Average Reward = -52.56  Number_drops:414 steps:70
# Episode 430 : Average Reward = -52.26  Number_drops:415 steps:41
# Episode 431 : Average Reward = -52.59  Number_drops:416 steps:44
# Episode 432 : Average Reward = -53.11  Number_drops:417 steps:94
# Episode 433 : Average Reward = -52.62  Number_drops:418 steps:20
# Episode 434 : Average Reward = -52.64  Number_drops:419 steps:57
# Episode 435 : Average Reward = -52.27  Number_drops:420 steps:68
# Episode 436 : Average Reward = -52.97  Number_drops:421 steps:100
# Episode 437 : Average Reward = -53.1  Number_drops:422 steps:40
# Episode 438 : Average Reward = -53.05  Number_drops:423 steps:68
# Episode 439 : Average Reward = -53.05  Number_drops:424 steps:17
# Episode 440 : Average Reward = -53.51  Number_drops:425 steps:74
# Episode 441 : Average Reward = -53.79  Number_drops:426 steps:40
# Episode 442 : Average Reward = -53.27  Number_drops:427 steps:50
# Episode 443 : Average Reward = -53.35  Number_drops:428 steps:48
# Episode 444 : Average Reward = -52.59  Number_drops:429 steps:11
# Episode 445 : Average Reward = -52.17  Number_drops:430 steps:50
# Episode 446 : Average Reward = -51.79  Number_drops:431 steps:60
# Episode 447 : Average Reward = -51.9  Number_drops:432 steps:61
# Episode 448 : Average Reward = -51.59  Number_drops:433 steps:13
# Episode 449 : Average Reward = -51.25  Number_drops:434 steps:28
# Episode 450 : Average Reward = -51.3  Number_drops:435 steps:96
# Episode 451 : Average Reward = -51.04  Number_drops:436 steps:18
# Episode 452 : Average Reward = -50.5  Number_drops:437 steps:26
# Episode 453 : Average Reward = -50.91  Number_drops:438 steps:127
# Episode 454 : Average Reward = -50.95  Number_drops:439 steps:80
# Episode 455 : Average Reward = -50.74  Number_drops:440 steps:7
# Episode 456 : Average Reward = -50.97  Number_drops:441 steps:109
# Episode 457 : Average Reward = -50.47  Number_drops:442 steps:13
# Episode 458 : Average Reward = -51.04  Number_drops:443 steps:71
# Episode 459 : Average Reward = -50.88  Number_drops:444 steps:17
# Episode 460 : Average Reward = -50.02  Number_drops:445 steps:9
# Episode 461 : Average Reward = -50.02  Number_drops:446 steps:40
# Episode 462 : Average Reward = -50.24  Number_drops:447 steps:104
# Episode 463 : Average Reward = -51.26  Number_drops:448 steps:112
# Episode 464 : Average Reward = -50.94  Number_drops:449 steps:25
# Episode 465 : Average Reward = -51.44  Number_drops:450 steps:122
# Episode 466 : Average Reward = -51.93  Number_drops:451 steps:86
# Episode 467 : Average Reward = -51.99  Number_drops:452 steps:31
# Episode 468 : Average Reward = -52.17  Number_drops:453 steps:77
# Episode 469 : Average Reward = -51.62  Number_drops:454 steps:21
# Episode 470 : Average Reward = -51.52  Number_drops:455 steps:24
# Episode 471 : Average Reward = -51.92  Number_drops:456 steps:54
# Episode 472 : Average Reward = -51.73  Number_drops:457 steps:84
# Episode 473 : Average Reward = -51.33  Number_drops:458 steps:10
# Episode 474 : Average Reward = -51.95  Number_drops:459 steps:92
# Episode 475 : Average Reward = -52.02  Number_drops:460 steps:55
# Episode 476 : Average Reward = -51.79  Number_drops:461 steps:41
# Episode 477 : Average Reward = -52.15  Number_drops:462 steps:74
# Episode 478 : Average Reward = -52.25  Number_drops:463 steps:84
# Episode 479 : Average Reward = -52.33  Number_drops:464 steps:68
# Episode 480 : Average Reward = -51.79  Number_drops:465 steps:14
# Episode 481 : Average Reward = -51.88  Number_drops:466 steps:32
# Episode 482 : Average Reward = -51.01  Number_drops:467 steps:23
# Episode 483 : Average Reward = -51.36  Number_drops:468 steps:76
# Episode 484 : Average Reward = -50.99  Number_drops:469 steps:33
# Episode 485 : Average Reward = -51.25  Number_drops:470 steps:60
# Episode 486 : Average Reward = -51.71  Number_drops:471 steps:68
# Episode 487 : Average Reward = -50.8  Number_drops:472 steps:10
# Episode 488 : Average Reward = -50.86  Number_drops:473 steps:26
# Episode 489 : Average Reward = -50.74  Number_drops:474 steps:18
# Episode 490 : Average Reward = -50.9  Number_drops:475 steps:47
# Episode 491 : Average Reward = -51.24  Number_drops:476 steps:71
# Episode 492 : Average Reward = -50.87  Number_drops:477 steps:21
# Episode 493 : Average Reward = -51.47  Number_drops:478 steps:110
# Episode 494 : Average Reward = -50.98  Number_drops:479 steps:34
# Episode 495 : Average Reward = -49.87  Number_drops:480 steps:29
# Episode 496 : Average Reward = -49.64  Number_drops:481 steps:36
# Episode 497 : Average Reward = -49.65  Number_drops:482 steps:35
# Episode 498 : Average Reward = -49.31  Number_drops:483 steps:64
# Episode 499 : Average Reward = -49.58  Number_drops:484 steps:50
# Episode 500 : Average Reward = -49.5  Number_drops:485 steps:18
# Episode 501 : Average Reward = -49.6  Number_drops:486 steps:26
# Episode 502 : Average Reward = -49.23  Number_drops:487 steps:31
# Episode 503 : Average Reward = -48.8  Number_drops:488 steps:21
# Episode 504 : Average Reward = -48.44  Number_drops:489 steps:40
# Episode 505 : Average Reward = -48.72  Number_drops:490 steps:54
# Episode 506 : Average Reward = -48.92  Number_drops:491 steps:91
# Episode 507 : Average Reward = -49.5  Number_drops:492 steps:75
# Episode 508 : Average Reward = -49.72  Number_drops:493 steps:88
# Episode 509 : Average Reward = -49.48  Number_drops:494 steps:61
# Episode 510 : Average Reward = -50.13  Number_drops:495 steps:95
# Episode 511 : Average Reward = -49.97  Number_drops:496 steps:30
# Episode 512 : Average Reward = -49.94  Number_drops:497 steps:31
# Episode 513 : Average Reward = -50.23  Number_drops:498 steps:73
# Episode 514 : Average Reward = -49.5  Number_drops:499 steps:11
# Episode 515 : Average Reward = -49.5  Number_drops:500 steps:27
# Episode 516 : Average Reward = -49.25  Number_drops:501 steps:29
# Episode 517 : Average Reward = -48.91  Number_drops:502 steps:34
# Episode 518 : Average Reward = -48.77  Number_drops:503 steps:34
# Episode 519 : Average Reward = -48.85  Number_drops:504 steps:50
# Episode 520 : Average Reward = -48.93  Number_drops:505 steps:26
# Episode 521 : Average Reward = -49.25  Number_drops:506 steps:67
# Episode 522 : Average Reward = -49.31  Number_drops:507 steps:34
# Episode 523 : Average Reward = -49.46  Number_drops:508 steps:27
# Episode 524 : Average Reward = -49.78  Number_drops:509 steps:72
# Episode 525 : Average Reward = -49.34  Number_drops:510 steps:22
# Episode 526 : Average Reward = -49.12  Number_drops:511 steps:12
# Episode 527 : Average Reward = -49.47  Number_drops:512 steps:70
# Episode 528 : Average Reward = -50.07  Number_drops:513 steps:70
# Episode 529 : Average Reward = -49.64  Number_drops:514 steps:27
# Episode 530 : Average Reward = -50.02  Number_drops:515 steps:79
# Episode 531 : Average Reward = -50.56  Number_drops:516 steps:98
# Episode 532 : Average Reward = -49.94  Number_drops:517 steps:32
# Episode 533 : Average Reward = -50.44  Number_drops:518 steps:70
# Episode 534 : Average Reward = -50.25  Number_drops:519 steps:38
# Episode 535 : Average Reward = -49.69  Number_drops:520 steps:12
# Episode 536 : Average Reward = -49.69  Number_drops:521 steps:100
# Episode 537 : Average Reward = -49.89  Number_drops:522 steps:60
# Episode 538 : Average Reward = -49.52  Number_drops:523 steps:31
# Episode 539 : Average Reward = -49.59  Number_drops:524 steps:24
# Episode 540 : Average Reward = -49.13  Number_drops:525 steps:28
# Episode 541 : Average Reward = -49.15  Number_drops:526 steps:42
# Episode 542 : Average Reward = -48.99  Number_drops:527 steps:34
# Episode 543 : Average Reward = -49.44  Number_drops:528 steps:93
# Episode 544 : Average Reward = -49.63  Number_drops:529 steps:30
# Episode 545 : Average Reward = -49.46  Number_drops:530 steps:33
# Episode 546 : Average Reward = -49.12  Number_drops:531 steps:26
# Episode 547 : Average Reward = -48.76  Number_drops:532 steps:25
# Episode 548 : Average Reward = -49.31  Number_drops:533 steps:68
# Episode 549 : Average Reward = -49.73  Number_drops:534 steps:70
# Episode 550 : Average Reward = -49.02  Number_drops:535 steps:25
# Episode 551 : Average Reward = -49.44  Number_drops:536 steps:60
# Episode 552 : Average Reward = -49.38  Number_drops:537 steps:20
# Episode 553 : Average Reward = -48.35  Number_drops:538 steps:24
# Episode 554 : Average Reward = -47.77  Number_drops:539 steps:22
# Episode 555 : Average Reward = -48.55  Number_drops:540 steps:85
# Episode 556 : Average Reward = -47.91  Number_drops:541 steps:45
# Episode 557 : Average Reward = -47.94  Number_drops:542 steps:16
# Episode 558 : Average Reward = -47.83  Number_drops:543 steps:60
# Episode 559 : Average Reward = -48.11  Number_drops:544 steps:45
# Episode 560 : Average Reward = -48.12  Number_drops:545 steps:10
# Episode 561 : Average Reward = -48.03  Number_drops:546 steps:31
# Episode 562 : Average Reward = -47.23  Number_drops:547 steps:24
# Episode 563 : Average Reward = -46.24  Number_drops:548 steps:13
# Episode 564 : Average Reward = -46.46  Number_drops:549 steps:47
# Episode 565 : Average Reward = -45.4  Number_drops:550 steps:16
# Episode 566 : Average Reward = -44.64  Number_drops:551 steps:10
# Episode 567 : Average Reward = -44.63  Number_drops:552 steps:30
# Episode 568 : Average Reward = -44.2  Number_drops:553 steps:34
# Episode 569 : Average Reward = -44.21  Number_drops:554 steps:22
# Episode 570 : Average Reward = -44.71  Number_drops:555 steps:74
# Episode 571 : Average Reward = -44.42  Number_drops:556 steps:25
# Episode 572 : Average Reward = -44.1  Number_drops:557 steps:52
# Episode 573 : Average Reward = -44.44  Number_drops:558 steps:44
# Episode 574 : Average Reward = -43.78  Number_drops:559 steps:26
# Episode 575 : Average Reward = -43.63  Number_drops:560 steps:40
# Episode 576 : Average Reward = -43.61  Number_drops:561 steps:39
# Episode 577 : Average Reward = -43.19  Number_drops:562 steps:32
# Episode 578 : Average Reward = -42.51  Number_drops:563 steps:16
# Episode 579 : Average Reward = -42.56  Number_drops:564 steps:73
# Episode 580 : Average Reward = -42.84  Number_drops:565 steps:42
# Episode 581 : Average Reward = -42.66  Number_drops:566 steps:14
# Episode 582 : Average Reward = -43.18  Number_drops:567 steps:75
# Episode 583 : Average Reward = -42.68  Number_drops:568 steps:26
# Episode 584 : Average Reward = -42.87  Number_drops:569 steps:52
# Episode 585 : Average Reward = -42.89  Number_drops:570 steps:62
# Episode 586 : Average Reward = -42.47  Number_drops:571 steps:26
# Episode 587 : Average Reward = -43.05  Number_drops:572 steps:68
# Episode 588 : Average Reward = -43.21  Number_drops:573 steps:42
# Episode 589 : Average Reward = -43.63  Number_drops:574 steps:60
# Episode 590 : Average Reward = -43.86  Number_drops:575 steps:70
# Episode 591 : Average Reward = -43.51  Number_drops:576 steps:36
# Episode 592 : Average Reward = -43.63  Number_drops:577 steps:33
# Episode 593 : Average Reward = -42.83  Number_drops:578 steps:30
# Episode 594 : Average Reward = -42.73  Number_drops:579 steps:24
# Episode 595 : Average Reward = -43.18  Number_drops:580 steps:74
# Episode 596 : Average Reward = -43.0  Number_drops:581 steps:18
# Episode 597 : Average Reward = -43.33  Number_drops:582 steps:68
# Episode 598 : Average Reward = -42.93  Number_drops:583 steps:24
# Episode 599 : Average Reward = -42.84  Number_drops:584 steps:41
# Episode 600 : Average Reward = -42.94  Number_drops:585 steps:28
# Episode 601 : Average Reward = -42.91  Number_drops:586 steps:23
# Episode 602 : Average Reward = -42.83  Number_drops:587 steps:23
# Episode 603 : Average Reward = -42.95  Number_drops:588 steps:33
# Episode 604 : Average Reward = -42.97  Number_drops:589 steps:42
# Episode 605 : Average Reward = -42.77  Number_drops:590 steps:34
# Episode 606 : Average Reward = -42.16  Number_drops:591 steps:30
# Episode 607 : Average Reward = -41.54  Number_drops:592 steps:13
# Episode 608 : Average Reward = -40.88  Number_drops:593 steps:22
# Episode 609 : Average Reward = -40.78  Number_drops:594 steps:51
# Episode 610 : Average Reward = -39.98  Number_drops:595 steps:15
# Episode 611 : Average Reward = -40.85  Number_drops:596 steps:117
# Episode 612 : Average Reward = -41.18  Number_drops:597 steps:64
# Episode 613 : Average Reward = -40.6  Number_drops:598 steps:15
# Episode 614 : Average Reward = -40.69  Number_drops:599 steps:20
# Episode 615 : Average Reward = -41.18  Number_drops:600 steps:76
# Episode 616 : Average Reward = -41.43  Number_drops:601 steps:54
# Episode 617 : Average Reward = -41.53  Number_drops:602 steps:44
# Episode 618 : Average Reward = -41.86  Number_drops:603 steps:67
# Episode 619 : Average Reward = -41.66  Number_drops:604 steps:30
# Episode 620 : Average Reward = -42.81  Number_drops:605 steps:141
# Episode 621 : Average Reward = -42.66  Number_drops:606 steps:52
# Episode 622 : Average Reward = -42.5  Number_drops:607 steps:18
# Episode 623 : Average Reward = -42.77  Number_drops:608 steps:54
# Episode 624 : Average Reward = -42.13  Number_drops:609 steps:8
# Episode 625 : Average Reward = -42.25  Number_drops:610 steps:34
# Episode 626 : Average Reward = -42.75  Number_drops:611 steps:62
# Episode 627 : Average Reward = -42.28  Number_drops:612 steps:23
# Episode 628 : Average Reward = -41.7  Number_drops:613 steps:12
# Episode 629 : Average Reward = -41.54  Number_drops:614 steps:11
# Episode 630 : Average Reward = -41.53  Number_drops:615 steps:78
# Episode 631 : Average Reward = -40.66  Number_drops:616 steps:11
# Episode 632 : Average Reward = -41.43  Number_drops:617 steps:109
# Episode 633 : Average Reward = -41.39  Number_drops:618 steps:66
# Episode 634 : Average Reward = -41.44  Number_drops:619 steps:43
# Episode 635 : Average Reward = -41.64  Number_drops:620 steps:32
# Episode 636 : Average Reward = -41.02  Number_drops:621 steps:38
# Episode 637 : Average Reward = -41.12  Number_drops:622 steps:70
# Episode 638 : Average Reward = -41.31  Number_drops:623 steps:50
# Episode 639 : Average Reward = -41.29  Number_drops:624 steps:22
# Episode 640 : Average Reward = -41.31  Number_drops:625 steps:30
# Episode 641 : Average Reward = -41.39  Number_drops:626 steps:50
# Episode 642 : Average Reward = -41.25  Number_drops:627 steps:20
# Episode 643 : Average Reward = -40.68  Number_drops:628 steps:36
# Episode 644 : Average Reward = -40.78  Number_drops:629 steps:40
# Episode 645 : Average Reward = -40.79  Number_drops:630 steps:34
# Episode 646 : Average Reward = -40.73  Number_drops:631 steps:20
# Episode 647 : Average Reward = -40.76  Number_drops:632 steps:28
# Episode 648 : Average Reward = -40.44  Number_drops:633 steps:36
# Episode 649 : Average Reward = -39.96  Number_drops:634 steps:22
# Episode 650 : Average Reward = -39.85  Number_drops:635 steps:14
# Episode 651 : Average Reward = -40.3  Number_drops:636 steps:105
# Episode 652 : Average Reward = -40.27  Number_drops:637 steps:17
# Episode 653 : Average Reward = -40.37  Number_drops:638 steps:34
# Episode 654 : Average Reward = -40.55  Number_drops:639 steps:40
# Episode 655 : Average Reward = -40.08  Number_drops:640 steps:38
# Episode 656 : Average Reward = -39.96  Number_drops:641 steps:33
# Episode 657 : Average Reward = -40.28  Number_drops:642 steps:48
# Episode 658 : Average Reward = -40.48  Number_drops:643 steps:80
# Episode 659 : Average Reward = -40.61  Number_drops:644 steps:58
# Episode 660 : Average Reward = -41.06  Number_drops:645 steps:55
# Episode 661 : Average Reward = -41.16  Number_drops:646 steps:41
# Episode 662 : Average Reward = -41.25  Number_drops:647 steps:33
# Episode 663 : Average Reward = -41.72  Number_drops:648 steps:60
# Episode 664 : Average Reward = -41.34  Number_drops:649 steps:9
# Episode 665 : Average Reward = -42.11  Number_drops:650 steps:93
# Episode 666 : Average Reward = -42.24  Number_drops:651 steps:23
# Episode 667 : Average Reward = -42.27  Number_drops:652 steps:33
# Episode 668 : Average Reward = -42.04  Number_drops:653 steps:11
# Episode 669 : Average Reward = -41.91  Number_drops:654 steps:9
# Episode 670 : Average Reward = -41.34  Number_drops:655 steps:17
# Episode 671 : Average Reward = -41.19  Number_drops:656 steps:10
# Episode 672 : Average Reward = -41.44  Number_drops:657 steps:77
# Episode 673 : Average Reward = -41.32  Number_drops:658 steps:32
# Episode 674 : Average Reward = -41.4  Number_drops:659 steps:34
# Episode 675 : Average Reward = -41.24  Number_drops:660 steps:24
# Episode 676 : Average Reward = -41.02  Number_drops:661 steps:17
# Episode 677 : Average Reward = -40.82  Number_drops:662 steps:12
# Episode 678 : Average Reward = -41.0  Number_drops:663 steps:34
# Episode 679 : Average Reward = -40.85  Number_drops:664 steps:58
# Episode 680 : Average Reward = -40.87  Number_drops:665 steps:44
# Episode 681 : Average Reward = -40.88  Number_drops:666 steps:15
# Episode 682 : Average Reward = -40.69  Number_drops:667 steps:56
# Episode 683 : Average Reward = -40.48  Number_drops:668 steps:5
# Episode 684 : Average Reward = -40.23  Number_drops:669 steps:27
# Episode 685 : Average Reward = -40.13  Number_drops:670 steps:52
# Episode 686 : Average Reward = -40.02  Number_drops:671 steps:15
# Episode 687 : Average Reward = -39.88  Number_drops:672 steps:54
# Episode 688 : Average Reward = -39.88  Number_drops:673 steps:42
# Episode 689 : Average Reward = -39.76  Number_drops:674 steps:48
# Episode 690 : Average Reward = -39.19  Number_drops:675 steps:13
# Episode 691 : Average Reward = -39.09  Number_drops:676 steps:26
# Episode 692 : Average Reward = -39.36  Number_drops:677 steps:60
# Episode 693 : Average Reward = -39.88  Number_drops:678 steps:82
# Episode 694 : Average Reward = -40.68  Number_drops:679 steps:104
# Episode 695 : Average Reward = -40.58  Number_drops:680 steps:64
# Episode 696 : Average Reward = -40.58  Number_drops:681 steps:18
# Episode 697 : Average Reward = -40.08  Number_drops:682 steps:18
# Episode 698 : Average Reward = -40.14  Number_drops:683 steps:30
# Episode 699 : Average Reward = -40.05  Number_drops:684 steps:32
# Episode 700 : Average Reward = -39.93  Number_drops:685 steps:16
# Episode 701 : Average Reward = -39.82  Number_drops:686 steps:12
# Episode 702 : Average Reward = -40.0  Number_drops:687 steps:41
# Episode 703 : Average Reward = -39.88  Number_drops:688 steps:21
# Episode 704 : Average Reward = -39.73  Number_drops:689 steps:27
# Episode 705 : Average Reward = -39.54  Number_drops:690 steps:15
# Episode 706 : Average Reward = -39.42  Number_drops:691 steps:18
# Episode 707 : Average Reward = -39.72  Number_drops:692 steps:43
# Episode 708 : Average Reward = -40.16  Number_drops:693 steps:66
# Episode 709 : Average Reward = -39.99  Number_drops:694 steps:34
# Episode 710 : Average Reward = -40.22  Number_drops:695 steps:38
# Episode 711 : Average Reward = -39.68  Number_drops:696 steps:63
# Episode 712 : Average Reward = -39.53  Number_drops:697 steps:49
# Episode 713 : Average Reward = -39.56  Number_drops:698 steps:18
# Episode 714 : Average Reward = -39.72  Number_drops:699 steps:36
# Episode 715 : Average Reward = -39.58  Number_drops:700 steps:62
# Episode 716 : Average Reward = -39.35  Number_drops:701 steps:31
# Episode 717 : Average Reward = -39.53  Number_drops:702 steps:62
# Episode 718 : Average Reward = -39.38  Number_drops:703 steps:52
# Episode 719 : Average Reward = -39.34  Number_drops:704 steps:26
# Episode 720 : Average Reward = -38.22  Number_drops:705 steps:29
# Episode 721 : Average Reward = -38.28  Number_drops:706 steps:58
# Episode 722 : Average Reward = -38.37  Number_drops:707 steps:27
# Episode 723 : Average Reward = -38.87  Number_drops:708 steps:104
# Episode 724 : Average Reward = -39.35  Number_drops:709 steps:56
# ...
# Episode 3262 : Average Reward = -25.31  Number_drops:3247 steps:38
# Episode 3263 : Average Reward = -25.48  Number_drops:3248 steps:34
# Episode 3264 : Average Reward = -25.6  Number_drops:3249 steps:34
# Episode 3265 : Average Reward = -25.61  Number_drops:3250 steps:22
# Episode 3266 : Average Reward = -25.97  Number_drops:3251 steps:52
# Episode 3267 : Average Reward = -26.18  Number_drops:3252 steps:40
# Episode 3268 : Average Reward = -26.27  Number_drops:3253 steps:32
# Episode 3269 : Average Reward = -26.46  Number_drops:3254 steps:35
# Episode 3270 : Average Reward = -26.43  Number_drops:3255 steps:16
# Episode 3271 : Average Reward = -26.47  Number_drops:3256 steps:22
# Episode 3272 : Average Reward = -26.51  Number_drops:3257 steps:15
# Episode 3273 : Average Reward = -26.59  Number_drops:3258 steps:20
# Episode 3274 : Average Reward = -26.84  Number_drops:3259 steps:38
# Episode 3275 : Average Reward = -26.85  Number_drops:3260 steps:38
# Episode 3276 : Average Reward = -26.63  Number_drops:3261 steps:30
# Episode 3277 : Average Reward = -26.57  Number_drops:3262 steps:16
# Episode 3278 : Average Reward = -27.24  Number_drops:3263 steps:94
# Episode 3279 : Average Reward = -27.26  Number_drops:3264 steps:32
# Episode 3280 : Average Reward = -27.28  Number_drops:3265 steps:13
# Episode 3281 : Average Reward = -27.4  Number_drops:3266 steps:30
# Episode 3282 : Average Reward = -27.1  Number_drops:3267 steps:22
# Episode 3283 : Average Reward = -27.0  Number_drops:3268 steps:32
# Episode 3284 : Average Reward = -26.84  Number_drops:3269 steps:18
# Episode 3285 : Average Reward = -26.82  Number_drops:3270 steps:22
# Episode 3286 : Average Reward = -26.94  Number_drops:3271 steps:26
# Episode 3287 : Average Reward = -27.08  Number_drops:3272 steps:44
# Episode 3288 : Average Reward = -26.98  Number_drops:3273 steps:14
# Episode 3289 : Average Reward = -26.62  Number_drops:3274 steps:12
# Episode 3290 : Average Reward = -26.41  Number_drops:3275 steps:13
# Episode 3291 : Average Reward = -26.56  Number_drops:3276 steps:24
# Episode 3292 : Average Reward = -26.46  Number_drops:3277 steps:8
# Episode 3293 : Average Reward = -26.39  Number_drops:3278 steps:16
# Episode 3294 : Average Reward = -26.52  Number_drops:3279 steps:30
# Episode 3295 : Average Reward = -26.44  Number_drops:3280 steps:28
# Episode 3296 : Average Reward = -26.08  Number_drops:3281 steps:10
# Episode 3297 : Average Reward = -26.18  Number_drops:3282 steps:38
# Episode 3298 : Average Reward = -26.0  Number_drops:3283 steps:20
# Episode 3299 : Average Reward = -26.05  Number_drops:3284 steps:15
# Episode 3300 : Average Reward = -25.92  Number_drops:3285 steps:11
# Episode 3301 : Average Reward = -25.96  Number_drops:3286 steps:28
# Episode 3302 : Average Reward = -26.02  Number_drops:3287 steps:24
# Episode 3303 : Average Reward = -26.12  Number_drops:3288 steps:42
# Episode 3304 : Average Reward = -26.01  Number_drops:3289 steps:28
# Episode 3305 : Average Reward = -25.98  Number_drops:3290 steps:40
# Episode 3306 : Average Reward = -25.95  Number_drops:3291 steps:8
# Episode 3307 : Average Reward = -25.99  Number_drops:3292 steps:18
# Episode 3308 : Average Reward = -25.91  Number_drops:3293 steps:20
# Episode 3309 : Average Reward = -25.72  Number_drops:3294 steps:20
# Episode 3310 : Average Reward = -25.62  Number_drops:3295 steps:46
# Episode 3311 : Average Reward = -25.58  Number_drops:3296 steps:24
# Episode 3312 : Average Reward = -25.8  Number_drops:3297 steps:42
# Episode 3313 : Average Reward = -26.17  Number_drops:3298 steps:52
# Episode 3314 : Average Reward = -26.48  Number_drops:3299 steps:50
# Episode 3315 : Average Reward = -26.28  Number_drops:3300 steps:10
# Episode 3316 : Average Reward = -26.45  Number_drops:3301 steps:28
# Episode 3317 : Average Reward = -26.47  Number_drops:3302 steps:24
# Episode 3318 : Average Reward = -26.26  Number_drops:3303 steps:15
# Episode 3319 : Average Reward = -26.23  Number_drops:3304 steps:11
# Episode 3320 : Average Reward = -26.16  Number_drops:3305 steps:18
# Episode 3321 : Average Reward = -26.28  Number_drops:3306 steps:32
# Episode 3322 : Average Reward = -26.2  Number_drops:3307 steps:28
# Episode 3323 : Average Reward = -26.24  Number_drops:3308 steps:24
# Episode 3324 : Average Reward = -26.08  Number_drops:3309 steps:12
# Episode 3325 : Average Reward = -26.09  Number_drops:3310 steps:12
# Episode 3326 : Average Reward = -26.04  Number_drops:3311 steps:15
# Episode 3327 : Average Reward = -25.85  Number_drops:3312 steps:12
# Episode 3328 : Average Reward = -25.89  Number_drops:3313 steps:32
# Episode 3329 : Average Reward = -25.71  Number_drops:3314 steps:12
# Episode 3330 : Average Reward = -25.75  Number_drops:3315 steps:19
# Episode 3331 : Average Reward = -25.44  Number_drops:3316 steps:15
# Episode 3332 : Average Reward = -25.16  Number_drops:3317 steps:20
# Episode 3333 : Average Reward = -24.96  Number_drops:3318 steps:10
# Episode 3334 : Average Reward = -24.81  Number_drops:3319 steps:21
# Episode 3335 : Average Reward = -24.64  Number_drops:3320 steps:11
# Episode 3336 : Average Reward = -24.64  Number_drops:3321 steps:32
# Episode 3337 : Average Reward = -24.64  Number_drops:3322 steps:20
# Episode 3338 : Average Reward = -24.69  Number_drops:3323 steps:20
# Episode 3339 : Average Reward = -24.65  Number_drops:3324 steps:14
# Episode 3340 : Average Reward = -24.85  Number_drops:3325 steps:52
# Episode 3341 : Average Reward = -24.72  Number_drops:3326 steps:8
# Episode 3342 : Average Reward = -24.73  Number_drops:3327 steps:20
# Episode 3343 : Average Reward = -24.7  Number_drops:3328 steps:11
# Episode 3344 : Average Reward = -24.8  Number_drops:3329 steps:26
# Episode 3345 : Average Reward = -24.87  Number_drops:3330 steps:38
# Episode 3346 : Average Reward = -25.55  Number_drops:3331 steps:88
# Episode 3347 : Average Reward = -25.51  Number_drops:3332 steps:10
# Episode 3348 : Average Reward = -25.65  Number_drops:3333 steps:22
# Episode 3349 : Average Reward = -25.5  Number_drops:3334 steps:16
# Episode 3350 : Average Reward = -25.43  Number_drops:3335 steps:16
# Episode 3351 : Average Reward = -25.21  Number_drops:3336 steps:13
# Episode 3352 : Average Reward = -25.33  Number_drops:3337 steps:19
# Episode 3353 : Average Reward = -25.36  Number_drops:3338 steps:44
# Episode 3354 : Average Reward = -25.48  Number_drops:3339 steps:22
# Episode 3355 : Average Reward = -25.26  Number_drops:3340 steps:10
# Episode 3356 : Average Reward = -25.29  Number_drops:3341 steps:18
# Episode 3357 : Average Reward = -25.34  Number_drops:3342 steps:22
# Episode 3358 : Average Reward = -25.18  Number_drops:3343 steps:24
# Episode 3359 : Average Reward = -25.57  Number_drops:3344 steps:49
# Episode 3360 : Average Reward = -25.63  Number_drops:3345 steps:32
# Episode 3361 : Average Reward = -25.65  Number_drops:3346 steps:42
# Episode 3362 : Average Reward = -25.38  Number_drops:3347 steps:11
# Episode 3363 : Average Reward = -25.23  Number_drops:3348 steps:19
# Episode 3364 : Average Reward = -24.98  Number_drops:3349 steps:9
# Episode 3365 : Average Reward = -24.98  Number_drops:3350 steps:22
# Episode 3366 : Average Reward = -24.67  Number_drops:3351 steps:21
# Episode 3367 : Average Reward = -24.49  Number_drops:3352 steps:22
# Episode 3368 : Average Reward = -24.37  Number_drops:3353 steps:20
# Episode 3369 : Average Reward = -24.13  Number_drops:3354 steps:11
# Episode 3370 : Average Reward = -24.09  Number_drops:3355 steps:12
# Episode 3371 : Average Reward = -24.01  Number_drops:3356 steps:14
# Episode 3372 : Average Reward = -24.1  Number_drops:3357 steps:24
# Episode 3373 : Average Reward = -24.03  Number_drops:3358 steps:13
# Episode 3374 : Average Reward = -23.81  Number_drops:3359 steps:16
# Episode 3375 : Average Reward = -23.53  Number_drops:3360 steps:10
# Episode 3376 : Average Reward = -23.34  Number_drops:3361 steps:11
# Episode 3377 : Average Reward = -23.56  Number_drops:3362 steps:38
# Episode 3378 : Average Reward = -22.78  Number_drops:3363 steps:16
# Episode 3379 : Average Reward = -22.72  Number_drops:3364 steps:26
# Episode 3380 : Average Reward = -22.83  Number_drops:3365 steps:24
# Episode 3381 : Average Reward = -22.89  Number_drops:3366 steps:36
# Episode 3382 : Average Reward = -22.89  Number_drops:3367 steps:22
# Episode 3383 : Average Reward = -22.67  Number_drops:3368 steps:10
# Episode 3384 : Average Reward = -23.02  Number_drops:3369 steps:53
# Episode 3385 : Average Reward = -23.02  Number_drops:3370 steps:22
# Episode 3386 : Average Reward = -22.89  Number_drops:3371 steps:13
# Episode 3387 : Average Reward = -22.55  Number_drops:3372 steps:10
# Episode 3388 : Average Reward = -22.88  Number_drops:3373 steps:47
# Episode 3389 : Average Reward = -23.0  Number_drops:3374 steps:24
# Episode 3390 : Average Reward = -23.03  Number_drops:3375 steps:16
# Episode 3391 : Average Reward = -23.01  Number_drops:3376 steps:22
# Episode 3392 : Average Reward = -23.31  Number_drops:3377 steps:38
# Episode 3393 : Average Reward = -23.24  Number_drops:3378 steps:9
# Episode 3394 : Average Reward = -23.26  Number_drops:3379 steps:32
# Episode 3395 : Average Reward = -23.26  Number_drops:3380 steps:28
# Episode 3396 : Average Reward = -23.36  Number_drops:3381 steps:20
# Episode 3397 : Average Reward = -23.24  Number_drops:3382 steps:26
# Episode 3398 : Average Reward = -23.15  Number_drops:3383 steps:11
# Episode 3399 : Average Reward = -23.11  Number_drops:3384 steps:11
# Episode 3400 : Average Reward = -23.17  Number_drops:3385 steps:17
# Episode 3401 : Average Reward = -23.29  Number_drops:3386 steps:40
# Episode 3402 : Average Reward = -23.41  Number_drops:3387 steps:36
# Episode 3403 : Average Reward = -23.18  Number_drops:3388 steps:19
# Episode 3404 : Average Reward = -23.12  Number_drops:3389 steps:22
# Episode 3405 : Average Reward = -22.92  Number_drops:3390 steps:20
# Episode 3406 : Average Reward = -23.01  Number_drops:3391 steps:17
# Episode 3407 : Average Reward = -23.51  Number_drops:3392 steps:68
# Episode 3408 : Average Reward = -23.47  Number_drops:3393 steps:16
# Episode 3409 : Average Reward = -23.62  Number_drops:3394 steps:35
# Episode 3410 : Average Reward = -23.58  Number_drops:3395 steps:42
# Episode 3411 : Average Reward = -23.62  Number_drops:3396 steps:28
# Episode 3412 : Average Reward = -23.36  Number_drops:3397 steps:16
# Episode 3413 : Average Reward = -23.06  Number_drops:3398 steps:22
# Episode 3414 : Average Reward = -22.76  Number_drops:3399 steps:20
# Episode 3415 : Average Reward = -22.8  Number_drops:3400 steps:14
# Episode 3416 : Average Reward = -22.66  Number_drops:3401 steps:14
# Episode 3417 : Average Reward = -22.54  Number_drops:3402 steps:12
# Episode 3418 : Average Reward = -22.72  Number_drops:3403 steps:33
# Episode 3419 : Average Reward = -22.7  Number_drops:3404 steps:9
# Episode 3420 : Average Reward = -22.92  Number_drops:3405 steps:40
# Episode 3421 : Average Reward = -22.8  Number_drops:3406 steps:20
# Episode 3422 : Average Reward = -23.06  Number_drops:3407 steps:54
# Episode 3423 : Average Reward = -22.92  Number_drops:3408 steps:10
# Episode 3424 : Average Reward = -22.91  Number_drops:3409 steps:11
# Episode 3425 : Average Reward = -23.17  Number_drops:3410 steps:38
# Episode 3426 : Average Reward = -23.2  Number_drops:3411 steps:18
# Episode 3427 : Average Reward = -23.36  Number_drops:3412 steps:28
# Episode 3428 : Average Reward = -23.28  Number_drops:3413 steps:24
# Episode 3429 : Average Reward = -23.42  Number_drops:3414 steps:26
# Episode 3430 : Average Reward = -23.32  Number_drops:3415 steps:9
# Episode 3431 : Average Reward = -23.41  Number_drops:3416 steps:24
# Episode 3432 : Average Reward = -23.39  Number_drops:3417 steps:18
# Episode 3433 : Average Reward = -23.61  Number_drops:3418 steps:32
# Episode 3434 : Average Reward = -23.59  Number_drops:3419 steps:19
# Episode 3435 : Average Reward = -23.72  Number_drops:3420 steps:24
# Episode 3436 : Average Reward = -23.56  Number_drops:3421 steps:16
# Episode 3437 : Average Reward = -23.56  Number_drops:3422 steps:20
# Episode 3438 : Average Reward = -23.58  Number_drops:3423 steps:22
# Episode 3439 : Average Reward = -23.59  Number_drops:3424 steps:15
# Episode 3440 : Average Reward = -23.31  Number_drops:3425 steps:24
# Episode 3441 : Average Reward = -23.39  Number_drops:3426 steps:16
# Episode 3442 : Average Reward = -23.61  Number_drops:3427 steps:42
# Episode 3443 : Average Reward = -23.78  Number_drops:3428 steps:28
# Episode 3444 : Average Reward = -23.68  Number_drops:3429 steps:16
# Episode 3445 : Average Reward = -23.44  Number_drops:3430 steps:14
# Episode 3446 : Average Reward = -22.68  Number_drops:3431 steps:12
# Episode 3447 : Average Reward = -22.78  Number_drops:3432 steps:20
# Episode 3448 : Average Reward = -22.87  Number_drops:3433 steps:31
# Episode 3449 : Average Reward = -22.93  Number_drops:3434 steps:22
# Episode 3450 : Average Reward = -22.93  Number_drops:3435 steps:16
# Episode 3451 : Average Reward = -23.0  Number_drops:3436 steps:20
# Episode 3452 : Average Reward = -23.03  Number_drops:3437 steps:22
# Episode 3453 : Average Reward = -22.87  Number_drops:3438 steps:28
# Episode 3454 : Average Reward = -22.76  Number_drops:3439 steps:11
# Episode 3455 : Average Reward = -22.8  Number_drops:3440 steps:14
# Episode 3456 : Average Reward = -22.85  Number_drops:3441 steps:23
# Episode 3457 : Average Reward = -22.91  Number_drops:3442 steps:28
# Episode 3458 : Average Reward = -22.99  Number_drops:3443 steps:32
# Episode 3459 : Average Reward = -22.82  Number_drops:3444 steps:32
# Episode 3460 : Average Reward = -22.62  Number_drops:3445 steps:12
# Episode 3461 : Average Reward = -22.62  Number_drops:3446 steps:42
# Episode 3462 : Average Reward = -22.83  Number_drops:3447 steps:32
# Episode 3463 : Average Reward = -22.91  Number_drops:3448 steps:27
# Episode 3464 : Average Reward = -22.93  Number_drops:3449 steps:11
# Episode 3465 : Average Reward = -23.32  Number_drops:3450 steps:61
# Episode 3466 : Average Reward = -23.23  Number_drops:3451 steps:12
# Episode 3467 : Average Reward = -23.35  Number_drops:3452 steps:34
# Episode 3468 : Average Reward = -23.47  Number_drops:3453 steps:32
# Episode 3469 : Average Reward = -23.46  Number_drops:3454 steps:10
# Episode 3470 : Average Reward = -23.55  Number_drops:3455 steps:21
# Episode 3471 : Average Reward = -23.77  Number_drops:3456 steps:36
# Episode 3472 : Average Reward = -23.87  Number_drops:3457 steps:34
# Episode 3473 : Average Reward = -23.92  Number_drops:3458 steps:18
# Episode 3474 : Average Reward = -24.18  Number_drops:3459 steps:42
# Episode 3475 : Average Reward = -24.2  Number_drops:3460 steps:12
# Episode 3476 : Average Reward = -24.31  Number_drops:3461 steps:22
# Episode 3477 : Average Reward = -24.4  Number_drops:3462 steps:47
# Episode 3478 : Average Reward = -24.46  Number_drops:3463 steps:22
# Episode 3479 : Average Reward = -24.4  Number_drops:3464 steps:20
# Episode 3480 : Average Reward = -24.38  Number_drops:3465 steps:22
# Episode 3481 : Average Reward = -24.11  Number_drops:3466 steps:9
# Episode 3482 : Average Reward = -24.39  Number_drops:3467 steps:50
# Episode 3483 : Average Reward = -24.46  Number_drops:3468 steps:17
# Episode 3484 : Average Reward = -24.19  Number_drops:3469 steps:26
# Episode 3485 : Average Reward = -24.47  Number_drops:3470 steps:50
# Episode 3486 : Average Reward = -24.76  Number_drops:3471 steps:42
# Episode 3487 : Average Reward = -25.02  Number_drops:3472 steps:36
# Episode 3488 : Average Reward = -24.76  Number_drops:3473 steps:21
# Episode 3489 : Average Reward = -24.76  Number_drops:3474 steps:24
# Episode 3490 : Average Reward = -24.87  Number_drops:3475 steps:27
# Episode 3491 : Average Reward = -24.72  Number_drops:3476 steps:7
# Episode 3492 : Average Reward = -24.7  Number_drops:3477 steps:36
# Episode 3493 : Average Reward = -24.93  Number_drops:3478 steps:32
# Episode 3494 : Average Reward = -24.82  Number_drops:3479 steps:21
# Episode 3495 : Average Reward = -24.7  Number_drops:3480 steps:16
# Episode 3496 : Average Reward = -24.71  Number_drops:3481 steps:21
# Episode 3497 : Average Reward = -24.62  Number_drops:3482 steps:17
# Episode 3498 : Average Reward = -24.77  Number_drops:3483 steps:26
# Episode 3499 : Average Reward = -25.22  Number_drops:3484 steps:56
# Episode 3500 : Average Reward = -25.29  Number_drops:3485 steps:24

# %% [markdown]
# # Testing Learned Policy

# %%
import matplotlib.pyplot as plt
window = 100
avg_rews_smdp = [np.average(rewards_smdp[i:i+window])
                 for i in range(len(rewards_smdp)-window)]
plt.plot(avg_rews_smdp, label='Model Score')
plt.xlabel('Episodes')
plt.ylabel('score averaged over previous 100 runs')
plt.title('SMDP over options with Q-learning Option policies')
plt.legend()
plt.axhline(y=8, color='red', linestyle='--')

# %%
state_array = np.array(state_counts, dtype="int")
num_substates = 20
fig, axes = plt.subplots(4, 5, figsize=(15, 12))

for substate in range(num_substates):
    substate_counts_1d = state_array[:, substate]
    substate_counts_2d = substate_counts_1d.reshape((5, 5))

    ax = axes[substate // 5, substate % 5]

    sns.heatmap(substate_counts_2d, annot=True,
                cmap='coolwarm', fmt='d', ax=ax)

    ax.set_title(
        f'(Passenger,Drop location)= {substate//nDrops,substate%nDrops}')

    ax.set_xlabel('Column')
    ax.set_ylabel('Row')

fig.suptitle('State Counts Heatmaps for Each Substate', fontsize=16)
plt.tight_layout()
plt.show()

# %%
env = gym.make("Taxi-v3", render_mode="human")
state, _ = env.reset()
done = False
in_taxi = False
q_values_SMDP = Q_smdp
total_reward = 0
x, y, pas, drop = env.decode(state)
print(f"Running for substate {nDrops*pas+drop}")
while not done:
    x, y, pas, drop = env.decode(state)
    subState = nDrops*pas+drop
    action = np.argmax(q_values_SMDP[5*x+y, subState])
    optdone = False
    move = 0
    prev = state
    while (optdone == False) and not done:
        x, y, pas, drop = env.decode(state)
        optdone = False
        if not optdone and not done:
            optact = action
            for j in range(2):
                taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(
                    state)
                next_state, reward, done, truncated, _ = env.step(optact)
                steps += 1
                taxi_row_new, taxi_col_new, passenger_location_id, drop_location_id = env.decode(
                    next_state)
                total_reward += reward
                reward_bar = gamma*reward_bar + reward
                reward_surr = reward
                locations = {0: [0, 0], 1: [0, 4], 2: [4, 0],
                             3: [4, 3], 4: [taxi_row, taxi_col]}
                loc = locations[passenger_location_id]
                taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(
                    next_state)
                if loc[0] == taxi_row and loc[1] == taxi_col and drop_location_id != passenger_location_id and not in_taxi:
                    optact = 4
                    in_taxi = True
                    optdone = True
                    next_state, reward, done, truncated, _ = env.step(optact)
                    total_reward += reward
                    break
                if goal[drop_location_id][0] == taxi_row and goal[drop_location_id][1] == taxi_col and passenger_location_id == 4:
                    optact = 5
                    optdone = True
                    number_drops += 1
                    next_state, reward, done, truncated, _ = env.step(optact)
                    total_reward += reward
                    break
                state = next_state
            optdone = True
print(f"Total Reward for this substate = {total_reward}")
# Out:
# Running for substate 1
# Total Reward for this substate = 1

# %%
import seaborn as sns
substates = 20
option_names = {
    0: "↑ 2",
    1: "↓ 2",
    2: "→ 2",
    3: "← 2"
}
num_substates = 20

fig, axes = plt.subplots(4, 5, figsize=(15, 12))

for substate in range(num_substates):
    learned_options = np.argmax(Q_smdp[:, substate], axis=1)
    learned_options_names = np.vectorize(option_names.get)(learned_options)
    learned_options_2d = learned_options.reshape((5, 5))
    annot_text = learned_options_names.reshape((5, 5))
    ax = axes[substate // 5, substate % 5]
    sns.heatmap(learned_options_2d, annot=annot_text,
                cmap='viridis', fmt='', ax=ax, cbar=False)
    ax.set_title(
        f'(Passenger,Drop location)= {substate//nDrops,substate%nDrops}')
    ax.set_xlabel('Column')
    ax.set_ylabel('Row')

fig.suptitle('Learned Options Heatmaps for Each Substate', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Intra Option Alternative option

# %%
from collections import deque
from tqdm import tqdm
import matplotlib.pyplot as plt

env = gym.make("Taxi-v3")
state, _ = env.reset()

number_drops = 0
gamma = 0.9
alpha = 0.4
number_options = 4
nPas = 5  # number of passengger locations
nDrops = 4  # number of drop locations

Q_intra = np.zeros((25, nPas*nDrops, number_options))

state_counts = np.zeros((25, nPas*nDrops))
epsilon_min = 0.01
decay_factor = 0.9
episodes = 10500
count = 0
rewards_smdp = []
# goal = {'top_x': 0, 'left_y': 0, 'bottom_x': 4, 'right_y': 4}
# action 0, 1 2 3  N S E W
eps_q = 0.1
score_history = deque(maxlen=100)
number_drops = 0
for i in range(episodes):
    state, _ = env.reset()
    done = False
    total_reward = 0
    truncated = False
    in_taxi = False
    action_counts = [0, 0, 0, 0]
    steps = 0
    while not done and not truncated:
        taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(
            state)
        subState = get_grid_no_drop(passenger_location_id, drop_location_id)
        action = epsilon_greedy(
            Q_intra[5*taxi_row+taxi_col], subState, epsilon=eps_q)
        eps_q = max(epsilon_min, eps_q*decay_factor)
        reward_bar = 0
        optdone = False
        k = 0
        prev = [taxi_row, taxi_col]
        state_counts[5*taxi_row+taxi_col, subState] += 1
        if not optdone and not done:
            optact = action
            for j in range(2):
                taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(
                    state)
                next_state, reward, done, truncated, _ = env.step(optact)
                steps += 1
                taxi_row_new, taxi_col_new, passenger_location_id, drop_location_id = env.decode(
                    next_state)

                state_counts[5*taxi_row_new+taxi_col_new, subState] += 1
                total_reward += reward
                reward_bar = gamma*reward_bar + reward
                k += 1
                reward_surr = reward

                # taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(
                #     next_state)
                locations = {0: [0, 0], 1: [0, 4], 2: [4, 0],
                             3: [4, 3], 4: [taxi_row, taxi_col]}
                loc = locations[passenger_location_id]
                subState = get_grid_no_drop(
                    passenger_location_id, drop_location_id)
                if loc[0] == taxi_row and loc[1] == taxi_col and drop_location_id != passenger_location_id and not in_taxi:
                    optact = 4
                    in_taxi = True
                    optdone = True
                    next_state2, reward, done, truncated, _ = env.step(optact)
                    taxi_row_new, taxi_col_new, passenger_location_id, drop_location_id = env.decode(
                        next_state2)

                    taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(
                        next_state)
                    target = (1-optdone) * \
                        Q_intra[5*taxi_row_new+taxi_col_new, subState, action] + \
                        optdone * \
                        np.max(Q_intra[5*taxi_row_new+taxi_col_new, subState])
                    Q_intra[5*taxi_row+taxi_col, subState, action] = Q_intra[5*taxi_row+taxi_col, subState, action] + \
                        alpha*(reward+gamma*target -
                               Q_intra[5*taxi_row+taxi_col, subState, action])
                    break

                if goal[drop_location_id][0] == taxi_row and goal[drop_location_id][1] == taxi_col and passenger_location_id == 4 and in_taxi:
                    optact = 5
                    optdone = True
                    number_drops += 1
                    next_state2, reward, done, truncated, _ = env.step(optact)
                    taxi_row_new, taxi_col_new, passenger_location_id, drop_location_id = env.decode(
                        next_state2)
                    taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(
                        next_state)

                    target = (1-optdone) * \
                        Q_intra[5*taxi_row_new+taxi_col_new, subState, action] + \
                        optdone * \
                        np.max(Q_intra[5*taxi_row_new+taxi_col_new, subState])
                    Q_intra[5*taxi_row+taxi_col, subState, action] = Q_intra[5*taxi_row+taxi_col, subState, action] + \
                        alpha*(reward+gamma*target -
                               Q_intra[5*taxi_row+taxi_col, subState, action])
                    break

                target = (1-optdone) * \
                    Q_intra[5*taxi_row_new+taxi_col_new, subState, action] + \
                    optdone * \
                    np.max(Q_intra[5*taxi_row_new+taxi_col_new, subState])
                Q_intra[5*taxi_row+taxi_col, subState, action] = Q_intra[5*taxi_row+taxi_col, subState, action] + \
                    alpha*(reward+gamma*target -
                           Q_intra[5*taxi_row+taxi_col, subState, action])
                state = next_state
            optdone = True

        # taxi_row_new, taxi_col_new, passenger_location_id, drop_location_id = env.decode(
        #     state)
        # Q_smdp[prev[0]*5+prev[1], dropgridno, action] += alpha*(reward_bar+(gamma**k)*np.max(
        #     Q_smdp[taxi_row_new*5+taxi_col_new, dropgridno])-Q_smdp[prev[0]*5+prev[1], dropgridno, action])

    rewards_smdp.append(total_reward)
    score_history.append(total_reward)
    if (i+1) % 1 == 0:
        print(
            f"Episode {i+1} : Average Reward = {np.mean(score_history)}  Number_drops:{number_drops} steps:{steps}")
# Out:
# Episode 1 : Average Reward = -94.0  Number_drops:1 steps:94
# Episode 2 : Average Reward = -122.5  Number_drops:2 steps:151
# Episode 3 : Average Reward = -148.0  Number_drops:2 steps:199
# Episode 4 : Average Reward = -160.75  Number_drops:2 steps:199
# Episode 5 : Average Reward = -145.2  Number_drops:3 steps:83
# Episode 6 : Average Reward = -139.83333333333334  Number_drops:4 steps:113
# Episode 7 : Average Reward = -148.42857142857142  Number_drops:4 steps:200
# Episode 8 : Average Reward = -143.0  Number_drops:5 steps:105
# Episode 9 : Average Reward = -148.88888888888889  Number_drops:6 steps:196
# Episode 10 : Average Reward = -150.0  Number_drops:7 steps:160
# Episode 11 : Average Reward = -148.0  Number_drops:8 steps:128
# Episode 12 : Average Reward = -144.83333333333334  Number_drops:9 steps:110
# Episode 13 : Average Reward = -145.23076923076923  Number_drops:10 steps:150
# Episode 14 : Average Reward = -149.14285714285714  Number_drops:10 steps:200
# Episode 15 : Average Reward = -148.66666666666666  Number_drops:11 steps:142
# Episode 16 : Average Reward = -151.8125  Number_drops:11 steps:199
# Episode 17 : Average Reward = -154.58823529411765  Number_drops:11 steps:199
# Episode 18 : Average Reward = -151.94444444444446  Number_drops:12 steps:107
# Episode 19 : Average Reward = -149.47368421052633  Number_drops:13 steps:105
# Episode 20 : Average Reward = -151.95  Number_drops:13 steps:199
# Episode 21 : Average Reward = -154.1904761904762  Number_drops:13 steps:199
# Episode 22 : Average Reward = -149.72727272727272  Number_drops:14 steps:56
# Episode 23 : Average Reward = -145.7826086956522  Number_drops:15 steps:59
# Episode 24 : Average Reward = -148.04166666666666  Number_drops:15 steps:200
# Episode 25 : Average Reward = -143.76  Number_drops:16 steps:41
# Episode 26 : Average Reward = -145.8846153846154  Number_drops:16 steps:199
# Episode 27 : Average Reward = -145.85185185185185  Number_drops:17 steps:145
# Episode 28 : Average Reward = -147.75  Number_drops:17 steps:199
# Episode 29 : Average Reward = -149.51724137931035  Number_drops:17 steps:199
# Episode 30 : Average Reward = -151.16666666666666  Number_drops:17 steps:199
# Episode 31 : Average Reward = -152.70967741935485  Number_drops:17 steps:199
# Episode 32 : Average Reward = -149.75  Number_drops:18 steps:58
# Episode 33 : Average Reward = -149.78787878787878  Number_drops:19 steps:151
# Episode 34 : Average Reward = -151.23529411764707  Number_drops:19 steps:199
# Episode 35 : Average Reward = -148.8  Number_drops:20 steps:66
# Episode 36 : Average Reward = -146.33333333333334  Number_drops:21 steps:60
# Episode 37 : Average Reward = -147.75675675675674  Number_drops:21 steps:199
# Episode 38 : Average Reward = -149.10526315789474  Number_drops:21 steps:199
# Episode 39 : Average Reward = -146.35897435897436  Number_drops:22 steps:42
# Episode 40 : Average Reward = -143.725  Number_drops:23 steps:41
# Episode 41 : Average Reward = -142.26829268292684  Number_drops:24 steps:84
# Episode 42 : Average Reward = -142.61904761904762  Number_drops:25 steps:157
# Episode 43 : Average Reward = -141.95348837209303  Number_drops:26 steps:114
# Episode 44 : Average Reward = -141.11363636363637  Number_drops:27 steps:105
# Episode 45 : Average Reward = -142.4  Number_drops:27 steps:199
# Episode 46 : Average Reward = -143.6304347826087  Number_drops:27 steps:199
# Episode 47 : Average Reward = -144.80851063829786  Number_drops:27 steps:199
# Episode 48 : Average Reward = -144.54166666666666  Number_drops:28 steps:132
# Episode 49 : Average Reward = -143.69387755102042  Number_drops:29 steps:103
# Episode 50 : Average Reward = -144.82  Number_drops:29 steps:200
# Episode 51 : Average Reward = -145.88235294117646  Number_drops:29 steps:199
# Episode 52 : Average Reward = -146.90384615384616  Number_drops:29 steps:199
# Episode 53 : Average Reward = -145.32075471698113  Number_drops:30 steps:63
# Episode 54 : Average Reward = -146.3148148148148  Number_drops:30 steps:199
# Episode 55 : Average Reward = -146.0  Number_drops:31 steps:129
# Episode 56 : Average Reward = -143.71428571428572  Number_drops:32 steps:18
# Episode 57 : Average Reward = -144.68421052631578  Number_drops:32 steps:199
# Episode 58 : Average Reward = -142.70689655172413  Number_drops:33 steps:30
# Episode 59 : Average Reward = -141.61016949152543  Number_drops:34 steps:78
# Episode 60 : Average Reward = -140.6  Number_drops:35 steps:81
# Episode 61 : Average Reward = -138.8360655737705  Number_drops:36 steps:33
# Episode 62 : Average Reward = -139.80645161290323  Number_drops:36 steps:199
# Episode 63 : Average Reward = -139.79365079365078  Number_drops:37 steps:139
# Episode 64 : Average Reward = -140.296875  Number_drops:38 steps:172
# Episode 65 : Average Reward = -141.2153846153846  Number_drops:38 steps:200
# Episode 66 : Average Reward = -140.84848484848484  Number_drops:39 steps:117
# Episode 67 : Average Reward = -141.71641791044777  Number_drops:39 steps:199
# Episode 68 : Average Reward = -142.55882352941177  Number_drops:39 steps:199
# Episode 69 : Average Reward = -143.3768115942029  Number_drops:39 steps:199
# Episode 70 : Average Reward = -142.44285714285715  Number_drops:40 steps:78
# Episode 71 : Average Reward = -141.56338028169014  Number_drops:41 steps:80
# Episode 72 : Average Reward = -141.58333333333334  Number_drops:42 steps:143
# Episode 73 : Average Reward = -142.36986301369862  Number_drops:42 steps:199
# Episode 74 : Average Reward = -142.04054054054055  Number_drops:43 steps:118
# Episode 75 : Average Reward = -142.8  Number_drops:43 steps:199
# Episode 76 : Average Reward = -141.80263157894737  Number_drops:44 steps:67
# Episode 77 : Average Reward = -141.02597402597402  Number_drops:45 steps:82
# Episode 78 : Average Reward = -140.5897435897436  Number_drops:46 steps:107
# Episode 79 : Average Reward = -141.34177215189874  Number_drops:46 steps:200
# Episode 80 : Average Reward = -140.8625  Number_drops:47 steps:103
# Episode 81 : Average Reward = -141.58024691358025  Number_drops:47 steps:199
# Episode 82 : Average Reward = -141.5  Number_drops:48 steps:135
# Episode 83 : Average Reward = -140.93975903614458  Number_drops:49 steps:95
# Episode 84 : Average Reward = -139.79761904761904  Number_drops:50 steps:45
# Episode 85 : Average Reward = -138.75294117647059  Number_drops:51 steps:51
# Episode 86 : Average Reward = -138.82558139534885  Number_drops:52 steps:145
# Episode 87 : Average Reward = -138.17241379310346  Number_drops:53 steps:82
# Episode 88 : Average Reward = -138.86363636363637  Number_drops:53 steps:199
# Episode 89 : Average Reward = -138.7078651685393  Number_drops:54 steps:125
# Episode 90 : Average Reward = -139.37777777777777  Number_drops:54 steps:199
# Episode 91 : Average Reward = -138.8021978021978  Number_drops:55 steps:87
# Episode 92 : Average Reward = -137.80434782608697  Number_drops:56 steps:47
# Episode 93 : Average Reward = -137.46236559139786  Number_drops:57 steps:106
# Episode 94 : Average Reward = -137.19148936170214  Number_drops:58 steps:112
# Episode 95 : Average Reward = -137.8421052631579  Number_drops:58 steps:199
# Episode 96 : Average Reward = -137.33333333333334  Number_drops:59 steps:89
# Episode 97 : Average Reward = -137.96907216494844  Number_drops:59 steps:199
# Episode 98 : Average Reward = -136.69387755102042  Number_drops:60 steps:13
# Episode 99 : Average Reward = -135.6060606060606  Number_drops:61 steps:29
# Episode 100 : Average Reward = -136.24  Number_drops:61 steps:199
# Episode 101 : Average Reward = -136.05  Number_drops:62 steps:75
# Episode 102 : Average Reward = -135.42  Number_drops:63 steps:88
# Episode 103 : Average Reward = -135.42  Number_drops:63 steps:199
# Episode 104 : Average Reward = -134.46  Number_drops:64 steps:103
# Episode 105 : Average Reward = -134.78  Number_drops:65 steps:115
# Episode 106 : Average Reward = -134.51  Number_drops:66 steps:86
# Episode 107 : Average Reward = -134.18  Number_drops:67 steps:167
# Episode 108 : Average Reward = -133.55  Number_drops:68 steps:42
# Episode 109 : Average Reward = -132.83  Number_drops:69 steps:124
# Episode 110 : Average Reward = -132.68  Number_drops:70 steps:145
# Episode 111 : Average Reward = -131.69  Number_drops:71 steps:29
# Episode 112 : Average Reward = -130.71  Number_drops:72 steps:12
# Episode 113 : Average Reward = -131.2  Number_drops:72 steps:199
# Episode 114 : Average Reward = -130.0  Number_drops:73 steps:80
# Episode 115 : Average Reward = -128.76  Number_drops:74 steps:18
# Episode 116 : Average Reward = -127.8  Number_drops:75 steps:103
# Episode 117 : Average Reward = -125.89  Number_drops:76 steps:8
# Episode 118 : Average Reward = -126.81  Number_drops:76 steps:199
# Episode 119 : Average Reward = -126.12  Number_drops:77 steps:36
# Episode 120 : Average Reward = -126.12  Number_drops:77 steps:199
# Episode 121 : Average Reward = -124.94  Number_drops:78 steps:81
# Episode 122 : Average Reward = -126.26  Number_drops:79 steps:188
# Episode 123 : Average Reward = -125.94  Number_drops:80 steps:27
# Episode 124 : Average Reward = -125.93  Number_drops:80 steps:199
# Episode 125 : Average Reward = -125.93  Number_drops:81 steps:41
# Episode 126 : Average Reward = -125.13  Number_drops:82 steps:119
# Episode 127 : Average Reward = -124.62  Number_drops:83 steps:94
# Episode 128 : Average Reward = -123.24  Number_drops:84 steps:61
# Episode 129 : Average Reward = -122.39  Number_drops:85 steps:114
# Episode 130 : Average Reward = -122.15  Number_drops:86 steps:175
# Episode 131 : Average Reward = -122.16  Number_drops:86 steps:200
# Episode 132 : Average Reward = -121.74  Number_drops:87 steps:16
# Episode 133 : Average Reward = -120.64  Number_drops:88 steps:41
# Episode 134 : Average Reward = -120.08  Number_drops:89 steps:143
# Episode 135 : Average Reward = -121.41  Number_drops:89 steps:199
# Episode 136 : Average Reward = -121.45  Number_drops:90 steps:64
# Episode 137 : Average Reward = -119.84  Number_drops:91 steps:38
# Episode 138 : Average Reward = -118.61  Number_drops:92 steps:76
# Episode 139 : Average Reward = -120.18  Number_drops:92 steps:199
# Episode 140 : Average Reward = -120.19  Number_drops:93 steps:42
# Episode 141 : Average Reward = -120.01  Number_drops:94 steps:66
# Episode 142 : Average Reward = -120.43  Number_drops:94 steps:199
# Episode 143 : Average Reward = -119.73  Number_drops:95 steps:44
# Episode 144 : Average Reward = -120.67  Number_drops:95 steps:199
# Episode 145 : Average Reward = -120.25  Number_drops:96 steps:157
# Episode 146 : Average Reward = -120.05  Number_drops:97 steps:179
# Episode 147 : Average Reward = -120.06  Number_drops:97 steps:200
# Episode 148 : Average Reward = -120.25  Number_drops:98 steps:151
# Episode 149 : Average Reward = -121.21  Number_drops:98 steps:199
# Episode 150 : Average Reward = -121.21  Number_drops:98 steps:200
# Episode 151 : Average Reward = -121.22  Number_drops:98 steps:200
# Episode 152 : Average Reward = -121.22  Number_drops:98 steps:199
# Episode 153 : Average Reward = -120.83  Number_drops:99 steps:24
# Episode 154 : Average Reward = -119.28  Number_drops:100 steps:44
# Episode 155 : Average Reward = -118.81  Number_drops:101 steps:82
# Episode 156 : Average Reward = -119.47  Number_drops:102 steps:84
# Episode 157 : Average Reward = -119.47  Number_drops:102 steps:199
# Episode 158 : Average Reward = -121.17  Number_drops:102 steps:200
# Episode 159 : Average Reward = -122.2  Number_drops:103 steps:181
# Episode 160 : Average Reward = -121.99  Number_drops:104 steps:60
# Episode 161 : Average Reward = -122.05  Number_drops:105 steps:39
# Episode 162 : Average Reward = -121.0  Number_drops:106 steps:94
# Episode 163 : Average Reward = -120.19  Number_drops:107 steps:58
# Episode 164 : Average Reward = -120.46  Number_drops:107 steps:199
# Episode 165 : Average Reward = -119.27  Number_drops:108 steps:81
# Episode 166 : Average Reward = -120.09  Number_drops:108 steps:199
# Episode 167 : Average Reward = -118.43  Number_drops:109 steps:33
# Episode 168 : Average Reward = -118.44  Number_drops:109 steps:200
# Episode 169 : Average Reward = -116.6  Number_drops:110 steps:15
# Episode 170 : Average Reward = -116.49  Number_drops:111 steps:67
# Episode 171 : Average Reward = -117.68  Number_drops:111 steps:199
# Episode 172 : Average Reward = -117.03  Number_drops:112 steps:78
# Episode 173 : Average Reward = -117.04  Number_drops:112 steps:200
# Episode 174 : Average Reward = -116.22  Number_drops:113 steps:36
# Episode 175 : Average Reward = -114.32  Number_drops:114 steps:9
# Episode 176 : Average Reward = -114.47  Number_drops:115 steps:82
# Episode 177 : Average Reward = -115.23  Number_drops:116 steps:158
# Episode 178 : Average Reward = -115.36  Number_drops:117 steps:120
# Episode 179 : Average Reward = -113.96  Number_drops:118 steps:60
# Episode 180 : Average Reward = -114.92  Number_drops:118 steps:199
# Episode 181 : Average Reward = -114.92  Number_drops:118 steps:199
# Episode 182 : Average Reward = -114.74  Number_drops:119 steps:117
# Episode 183 : Average Reward = -115.79  Number_drops:119 steps:200
# Episode 184 : Average Reward = -115.46  Number_drops:120 steps:12
# Episode 185 : Average Reward = -116.94  Number_drops:120 steps:199
# Episode 186 : Average Reward = -117.48  Number_drops:120 steps:199
# Episode 187 : Average Reward = -117.65  Number_drops:121 steps:99
# Episode 188 : Average Reward = -116.64  Number_drops:122 steps:98
# Episode 189 : Average Reward = -116.36  Number_drops:123 steps:97
# Episode 190 : Average Reward = -115.27  Number_drops:124 steps:90
# Episode 191 : Average Reward = -116.39  Number_drops:124 steps:199
# Episode 192 : Average Reward = -117.34  Number_drops:125 steps:142
# Episode 193 : Average Reward = -117.98  Number_drops:126 steps:170
# Episode 194 : Average Reward = -118.24  Number_drops:127 steps:138
# Episode 195 : Average Reward = -116.73  Number_drops:128 steps:48
# Episode 196 : Average Reward = -117.84  Number_drops:128 steps:200
# Episode 197 : Average Reward = -117.15  Number_drops:129 steps:130
# Episode 198 : Average Reward = -119.01  Number_drops:129 steps:199
# Episode 199 : Average Reward = -119.95  Number_drops:130 steps:123
# Episode 200 : Average Reward = -118.12  Number_drops:131 steps:16
# Episode 201 : Average Reward = -119.36  Number_drops:131 steps:199
# Episode 202 : Average Reward = -120.22  Number_drops:132 steps:174
# Episode 203 : Average Reward = -120.22  Number_drops:132 steps:199
# Episode 204 : Average Reward = -120.51  Number_drops:133 steps:132
# Episode 205 : Average Reward = -121.36  Number_drops:133 steps:200
# Episode 206 : Average Reward = -120.63  Number_drops:134 steps:13
# Episode 207 : Average Reward = -120.46  Number_drops:135 steps:150
# Episode 208 : Average Reward = -122.03  Number_drops:135 steps:199
# Episode 209 : Average Reward = -122.17  Number_drops:136 steps:138
# Episode 210 : Average Reward = -121.57  Number_drops:137 steps:85
# Episode 211 : Average Reward = -123.28  Number_drops:137 steps:200
# Episode 212 : Average Reward = -124.45  Number_drops:138 steps:129
# Episode 213 : Average Reward = -123.32  Number_drops:139 steps:86
# Episode 214 : Average Reward = -123.23  Number_drops:140 steps:71
# Episode 215 : Average Reward = -125.05  Number_drops:140 steps:200
# Episode 216 : Average Reward = -125.77  Number_drops:141 steps:175
# Episode 217 : Average Reward = -126.05  Number_drops:142 steps:36
# Episode 218 : Average Reward = -125.06  Number_drops:143 steps:100
# Episode 219 : Average Reward = -126.69  Number_drops:143 steps:199
# Episode 220 : Average Reward = -126.7  Number_drops:143 steps:200
# Episode 221 : Average Reward = -126.75  Number_drops:144 steps:86
# Episode 222 : Average Reward = -125.4  Number_drops:145 steps:53
# Episode 223 : Average Reward = -127.13  Number_drops:145 steps:200
# Episode 224 : Average Reward = -126.77  Number_drops:146 steps:163
# Episode 225 : Average Reward = -128.35  Number_drops:146 steps:199
# Episode 226 : Average Reward = -127.88  Number_drops:147 steps:72
# Episode 227 : Average Reward = -127.05  Number_drops:148 steps:11
# Episode 228 : Average Reward = -128.43  Number_drops:148 steps:199
# Episode 229 : Average Reward = -129.28  Number_drops:148 steps:199
# Episode 230 : Average Reward = -128.46  Number_drops:149 steps:93
# Episode 231 : Average Reward = -127.04  Number_drops:150 steps:58
# Episode 232 : Average Reward = -128.87  Number_drops:150 steps:199
# Episode 233 : Average Reward = -128.98  Number_drops:151 steps:52
# Episode 234 : Average Reward = -128.19  Number_drops:152 steps:64
# Episode 235 : Average Reward = -126.51  Number_drops:153 steps:31
# Episode 236 : Average Reward = -127.86  Number_drops:153 steps:199
# Episode 237 : Average Reward = -127.6  Number_drops:154 steps:12
# Episode 238 : Average Reward = -128.0  Number_drops:155 steps:116
# Episode 239 : Average Reward = -128.0  Number_drops:155 steps:199
# Episode 240 : Average Reward = -128.13  Number_drops:156 steps:55
# Episode 241 : Average Reward = -128.06  Number_drops:157 steps:59
# Episode 242 : Average Reward = -127.57  Number_drops:158 steps:150
# Episode 243 : Average Reward = -129.12  Number_drops:158 steps:199
# Episode 244 : Average Reward = -128.29  Number_drops:159 steps:116
# Episode 245 : Average Reward = -127.64  Number_drops:160 steps:92
# Episode 246 : Average Reward = -126.39  Number_drops:161 steps:54
# Episode 247 : Average Reward = -125.11  Number_drops:162 steps:72
# Episode 248 : Average Reward = -124.86  Number_drops:163 steps:126
# Episode 249 : Average Reward = -124.86  Number_drops:163 steps:199
# Episode 250 : Average Reward = -123.64  Number_drops:164 steps:78
# Episode 251 : Average Reward = -123.63  Number_drops:164 steps:199
# Episode 252 : Average Reward = -123.64  Number_drops:164 steps:200
# Episode 253 : Average Reward = -123.92  Number_drops:165 steps:52
# Episode 254 : Average Reward = -124.3  Number_drops:166 steps:82
# Episode 255 : Average Reward = -124.27  Number_drops:167 steps:79
# Episode 256 : Average Reward = -123.73  Number_drops:168 steps:30
# Episode 257 : Average Reward = -123.73  Number_drops:168 steps:199
# Episode 258 : Average Reward = -123.72  Number_drops:168 steps:199
# Episode 259 : Average Reward = -122.17  Number_drops:169 steps:26
# Episode 260 : Average Reward = -121.8  Number_drops:170 steps:23
# Episode 261 : Average Reward = -121.81  Number_drops:171 steps:40
# Episode 262 : Average Reward = -122.63  Number_drops:172 steps:176
# Episode 263 : Average Reward = -123.14  Number_drops:173 steps:109
# Episode 264 : Average Reward = -121.59  Number_drops:174 steps:44
# Episode 265 : Average Reward = -122.77  Number_drops:174 steps:199
# Episode 266 : Average Reward = -122.78  Number_drops:174 steps:200
# Episode 267 : Average Reward = -124.44  Number_drops:174 steps:199
# Episode 268 : Average Reward = -124.44  Number_drops:174 steps:200
# Episode 269 : Average Reward = -125.11  Number_drops:175 steps:82
# Episode 270 : Average Reward = -124.61  Number_drops:176 steps:17
# Episode 271 : Average Reward = -124.2  Number_drops:177 steps:158
# Episode 272 : Average Reward = -125.26  Number_drops:178 steps:184
# Episode 273 : Average Reward = -123.55  Number_drops:179 steps:29
# Episode 274 : Average Reward = -125.19  Number_drops:179 steps:200
# Episode 275 : Average Reward = -126.71  Number_drops:180 steps:161
# Episode 276 : Average Reward = -127.88  Number_drops:180 steps:199
# Episode 277 : Average Reward = -126.83  Number_drops:181 steps:53
# Episode 278 : Average Reward = -126.51  Number_drops:182 steps:88
# Episode 279 : Average Reward = -126.27  Number_drops:183 steps:36
# Episode 280 : Average Reward = -125.24  Number_drops:184 steps:96
# Episode 281 : Average Reward = -123.81  Number_drops:185 steps:56
# Episode 282 : Average Reward = -122.93  Number_drops:186 steps:29
# Episode 283 : Average Reward = -122.62  Number_drops:187 steps:169
# Episode 284 : Average Reward = -122.73  Number_drops:188 steps:23
# Episode 285 : Average Reward = -122.03  Number_drops:189 steps:129
# Episode 286 : Average Reward = -120.71  Number_drops:190 steps:67
# Episode 287 : Average Reward = -120.9  Number_drops:191 steps:118
# Episode 288 : Average Reward = -120.76  Number_drops:192 steps:84
# Episode 289 : Average Reward = -120.21  Number_drops:193 steps:42
# Episode 290 : Average Reward = -121.31  Number_drops:193 steps:200
# Episode 291 : Average Reward = -120.1  Number_drops:194 steps:78
# Episode 292 : Average Reward = -120.67  Number_drops:194 steps:199
# Episode 293 : Average Reward = -119.5  Number_drops:195 steps:53
# Episode 294 : Average Reward = -120.11  Number_drops:195 steps:199
# Episode 295 : Average Reward = -120.58  Number_drops:196 steps:95
# Episode 296 : Average Reward = -120.58  Number_drops:196 steps:200
# Episode 297 : Average Reward = -121.27  Number_drops:196 steps:199
# Episode 298 : Average Reward = -121.28  Number_drops:196 steps:200
# Episode 299 : Average Reward = -120.65  Number_drops:197 steps:60
# Episode 300 : Average Reward = -121.8  Number_drops:198 steps:131
# Episode 301 : Average Reward = -120.11  Number_drops:199 steps:30
# Episode 302 : Average Reward = -120.36  Number_drops:199 steps:199
# Episode 303 : Average Reward = -120.36  Number_drops:199 steps:199
# Episode 304 : Average Reward = -119.52  Number_drops:200 steps:48
# Episode 305 : Average Reward = -119.52  Number_drops:200 steps:200
# Episode 306 : Average Reward = -120.43  Number_drops:201 steps:104
# Episode 307 : Average Reward = -119.47  Number_drops:202 steps:54
# Episode 308 : Average Reward = -118.09  Number_drops:203 steps:61
# Episode 309 : Average Reward = -117.59  Number_drops:204 steps:88
# Episode 310 : Average Reward = -117.64  Number_drops:205 steps:90
# Episode 311 : Average Reward = -117.63  Number_drops:205 steps:199
# Episode 312 : Average Reward = -117.46  Number_drops:206 steps:112
# Episode 313 : Average Reward = -117.81  Number_drops:207 steps:121
# Episode 314 : Average Reward = -118.35  Number_drops:208 steps:125
# Episode 315 : Average Reward = -117.18  Number_drops:209 steps:83
# Episode 316 : Average Reward = -117.42  Number_drops:209 steps:199
# Episode 317 : Average Reward = -118.55  Number_drops:210 steps:149
# Episode 318 : Average Reward = -118.93  Number_drops:211 steps:138
# Episode 319 : Average Reward = -117.8  Number_drops:212 steps:86
# Episode 320 : Average Reward = -116.65  Number_drops:213 steps:85
# Episode 321 : Average Reward = -117.05  Number_drops:214 steps:126
# Episode 322 : Average Reward = -117.14  Number_drops:215 steps:62
# Episode 323 : Average Reward = -115.47  Number_drops:216 steps:33
# Episode 324 : Average Reward = -113.99  Number_drops:217 steps:15
# Episode 325 : Average Reward = -113.36  Number_drops:218 steps:136
# Episode 326 : Average Reward = -112.9  Number_drops:219 steps:26
# Episode 327 : Average Reward = -114.78  Number_drops:219 steps:199
# Episode 328 : Average Reward = -114.78  Number_drops:219 steps:199
# Episode 329 : Average Reward = -114.79  Number_drops:219 steps:200
# Episode 330 : Average Reward = -114.63  Number_drops:220 steps:77
# Episode 331 : Average Reward = -114.44  Number_drops:221 steps:39
# Episode 332 : Average Reward = -114.44  Number_drops:221 steps:199
# Episode 333 : Average Reward = -115.91  Number_drops:221 steps:199
# Episode 334 : Average Reward = -117.25  Number_drops:222 steps:198
# Episode 335 : Average Reward = -118.93  Number_drops:222 steps:199
# Episode 336 : Average Reward = -118.69  Number_drops:223 steps:175
# Episode 337 : Average Reward = -120.44  Number_drops:224 steps:187
# Episode 338 : Average Reward = -119.37  Number_drops:225 steps:9
# Episode 339 : Average Reward = -117.68  Number_drops:226 steps:30
# Episode 340 : Average Reward = -118.49  Number_drops:227 steps:136
# Episode 341 : Average Reward = -119.38  Number_drops:228 steps:148
# Episode 342 : Average Reward = -118.37  Number_drops:229 steps:49
# Episode 343 : Average Reward = -118.04  Number_drops:230 steps:166
# Episode 344 : Average Reward = -117.86  Number_drops:231 steps:98
# Episode 345 : Average Reward = -118.68  Number_drops:232 steps:174
# Episode 346 : Average Reward = -119.48  Number_drops:233 steps:134
# Episode 347 : Average Reward = -120.76  Number_drops:233 steps:200
# Episode 348 : Average Reward = -120.77  Number_drops:234 steps:127
# Episode 349 : Average Reward = -120.78  Number_drops:234 steps:200
# Episode 350 : Average Reward = -121.1  Number_drops:235 steps:110
# Episode 351 : Average Reward = -121.02  Number_drops:236 steps:191
# Episode 352 : Average Reward = -119.53  Number_drops:237 steps:51
# Episode 353 : Average Reward = -119.82  Number_drops:238 steps:81
# Episode 354 : Average Reward = -119.62  Number_drops:239 steps:62
# Episode 355 : Average Reward = -119.51  Number_drops:240 steps:68
# Episode 356 : Average Reward = -119.49  Number_drops:241 steps:28
# Episode 357 : Average Reward = -118.8  Number_drops:242 steps:130
# Episode 358 : Average Reward = -118.01  Number_drops:243 steps:120
# Episode 359 : Average Reward = -118.54  Number_drops:244 steps:79
# Episode 360 : Average Reward = -119.13  Number_drops:245 steps:82
# Episode 361 : Average Reward = -119.13  Number_drops:246 steps:40
# Episode 362 : Average Reward = -117.46  Number_drops:247 steps:9
# Episode 363 : Average Reward = -118.15  Number_drops:248 steps:178
# Episode 364 : Average Reward = -118.87  Number_drops:249 steps:116
# Episode 365 : Average Reward = -117.7  Number_drops:250 steps:82
# Episode 366 : Average Reward = -115.86  Number_drops:251 steps:16
# Episode 367 : Average Reward = -114.91  Number_drops:252 steps:104
# Episode 368 : Average Reward = -113.07  Number_drops:253 steps:16
# Episode 369 : Average Reward = -114.17  Number_drops:254 steps:192
# Episode 370 : Average Reward = -115.0  Number_drops:255 steps:100
# Episode 371 : Average Reward = -113.95  Number_drops:256 steps:53
# Episode 372 : Average Reward = -113.42  Number_drops:257 steps:131
# Episode 373 : Average Reward = -114.32  Number_drops:258 steps:119
# Episode 374 : Average Reward = -112.8  Number_drops:259 steps:48
# Episode 375 : Average Reward = -112.44  Number_drops:260 steps:125
# Episode 376 : Average Reward = -110.68  Number_drops:261 steps:23
# Episode 377 : Average Reward = -112.14  Number_drops:261 steps:199
# Episode 378 : Average Reward = -111.52  Number_drops:262 steps:26
# Episode 379 : Average Reward = -111.83  Number_drops:263 steps:67
# Episode 380 : Average Reward = -112.42  Number_drops:264 steps:155
# Episode 381 : Average Reward = -112.69  Number_drops:265 steps:83
# Episode 382 : Average Reward = -114.3  Number_drops:266 steps:190
# Episode 383 : Average Reward = -113.67  Number_drops:267 steps:106
# Episode 384 : Average Reward = -113.96  Number_drops:268 steps:52
# Episode 385 : Average Reward = -113.91  Number_drops:269 steps:124
# Episode 386 : Average Reward = -113.52  Number_drops:270 steps:28
# Episode 387 : Average Reward = -112.74  Number_drops:271 steps:40
# Episode 388 : Average Reward = -113.89  Number_drops:271 steps:199
# Episode 389 : Average Reward = -114.45  Number_drops:272 steps:98
# Episode 390 : Average Reward = -114.1  Number_drops:273 steps:165
# Episode 391 : Average Reward = -114.02  Number_drops:274 steps:70
# Episode 392 : Average Reward = -112.83  Number_drops:275 steps:80
# Episode 393 : Average Reward = -114.3  Number_drops:275 steps:200
# Episode 394 : Average Reward = -114.31  Number_drops:275 steps:200
# Episode 395 : Average Reward = -114.23  Number_drops:276 steps:87
# Episode 396 : Average Reward = -112.99  Number_drops:277 steps:76
# Episode 397 : Average Reward = -111.18  Number_drops:278 steps:18
# Episode 398 : Average Reward = -111.17  Number_drops:278 steps:199
# Episode 399 : Average Reward = -111.76  Number_drops:279 steps:119
# Episode 400 : Average Reward = -111.06  Number_drops:280 steps:61
# Episode 401 : Average Reward = -111.22  Number_drops:281 steps:46
# Episode 402 : Average Reward = -110.33  Number_drops:282 steps:110
# Episode 403 : Average Reward = -110.34  Number_drops:282 steps:200
# Episode 404 : Average Reward = -111.86  Number_drops:282 steps:200
# Episode 405 : Average Reward = -110.25  Number_drops:283 steps:39
# Episode 406 : Average Reward = -111.2  Number_drops:283 steps:199
# Episode 407 : Average Reward = -111.55  Number_drops:284 steps:89
# Episode 408 : Average Reward = -111.64  Number_drops:285 steps:70
# Episode 409 : Average Reward = -110.98  Number_drops:286 steps:22
# Episode 410 : Average Reward = -111.54  Number_drops:287 steps:146
# Episode 411 : Average Reward = -109.64  Number_drops:288 steps:9
# Episode 412 : Average Reward = -110.52  Number_drops:288 steps:200
# Episode 413 : Average Reward = -110.01  Number_drops:289 steps:70
# Episode 414 : Average Reward = -108.96  Number_drops:290 steps:20
# Episode 415 : Average Reward = -109.44  Number_drops:291 steps:131
# Episode 416 : Average Reward = -107.81  Number_drops:292 steps:36
# Episode 417 : Average Reward = -108.31  Number_drops:292 steps:199
# Episode 418 : Average Reward = -107.17  Number_drops:293 steps:24
# Episode 419 : Average Reward = -107.31  Number_drops:294 steps:100
# Episode 420 : Average Reward = -106.6  Number_drops:295 steps:14
# Episode 421 : Average Reward = -107.33  Number_drops:295 steps:199
# Episode 422 : Average Reward = -106.99  Number_drops:296 steps:28
# Episode 423 : Average Reward = -108.65  Number_drops:296 steps:199
# Episode 424 : Average Reward = -109.17  Number_drops:297 steps:67
# Episode 425 : Average Reward = -109.74  Number_drops:298 steps:193
# Episode 426 : Average Reward = -110.34  Number_drops:299 steps:86
# Episode 427 : Average Reward = -108.67  Number_drops:300 steps:32
# Episode 428 : Average Reward = -107.4  Number_drops:301 steps:72
# Episode 429 : Average Reward = -107.39  Number_drops:301 steps:199
# Episode 430 : Average Reward = -107.74  Number_drops:302 steps:112
# Episode 431 : Average Reward = -107.67  Number_drops:303 steps:32
# Episode 432 : Average Reward = -107.24  Number_drops:304 steps:156
# Episode 433 : Average Reward = -106.29  Number_drops:305 steps:104
# Episode 434 : Average Reward = -104.5  Number_drops:306 steps:19
# Episode 435 : Average Reward = -104.5  Number_drops:306 steps:199
# Episode 436 : Average Reward = -103.49  Number_drops:307 steps:74
# Episode 437 : Average Reward = -102.57  Number_drops:308 steps:95
# Episode 438 : Average Reward = -104.48  Number_drops:308 steps:200
# Episode 439 : Average Reward = -105.52  Number_drops:309 steps:134
# Episode 440 : Average Reward = -104.24  Number_drops:310 steps:8
# Episode 441 : Average Reward = -103.08  Number_drops:311 steps:32
# Episode 442 : Average Reward = -104.59  Number_drops:311 steps:200
# Episode 443 : Average Reward = -104.18  Number_drops:312 steps:125
# Episode 444 : Average Reward = -103.95  Number_drops:313 steps:75
# Episode 445 : Average Reward = -102.76  Number_drops:314 steps:55
# Episode 446 : Average Reward = -103.42  Number_drops:314 steps:200
# Episode 447 : Average Reward = -103.42  Number_drops:314 steps:200
# Episode 448 : Average Reward = -103.28  Number_drops:315 steps:113
# Episode 449 : Average Reward = -102.18  Number_drops:316 steps:90
# Episode 450 : Average Reward = -101.66  Number_drops:317 steps:58
# Episode 451 : Average Reward = -100.53  Number_drops:318 steps:78
# Episode 452 : Average Reward = -102.02  Number_drops:318 steps:200
# Episode 453 : Average Reward = -102.01  Number_drops:319 steps:80
# Episode 454 : Average Reward = -102.32  Number_drops:320 steps:93
# Episode 455 : Average Reward = -103.63  Number_drops:320 steps:199
# Episode 456 : Average Reward = -104.72  Number_drops:321 steps:137
# Episode 457 : Average Reward = -104.07  Number_drops:322 steps:65
# Episode 458 : Average Reward = -104.86  Number_drops:322 steps:199
# Episode 459 : Average Reward = -104.33  Number_drops:323 steps:26
# Episode 460 : Average Reward = -104.31  Number_drops:324 steps:80
# Episode 461 : Average Reward = -105.84  Number_drops:325 steps:193
# Episode 462 : Average Reward = -106.0  Number_drops:326 steps:25
# Episode 463 : Average Reward = -104.6  Number_drops:327 steps:38
# Episode 464 : Average Reward = -103.76  Number_drops:328 steps:32
# Episode 465 : Average Reward = -104.22  Number_drops:329 steps:128
# Episode 466 : Average Reward = -106.06  Number_drops:329 steps:200
# Episode 467 : Average Reward = -106.29  Number_drops:330 steps:127
# Episode 468 : Average Reward = -106.38  Number_drops:331 steps:25
# Episode 469 : Average Reward = -106.23  Number_drops:332 steps:177
# Episode 470 : Average Reward = -107.22  Number_drops:332 steps:199
# Episode 471 : Average Reward = -107.52  Number_drops:333 steps:83
# Episode 472 : Average Reward = -106.3  Number_drops:334 steps:9
# Episode 473 : Average Reward = -105.44  Number_drops:335 steps:33
# Episode 474 : Average Reward = -105.4  Number_drops:336 steps:44
# Episode 475 : Average Reward = -106.14  Number_drops:336 steps:199
# Episode 476 : Average Reward = -106.94  Number_drops:337 steps:103
# Episode 477 : Average Reward = -106.95  Number_drops:337 steps:200
# Episode 478 : Average Reward = -108.01  Number_drops:338 steps:132
# Episode 479 : Average Reward = -107.72  Number_drops:339 steps:38
# Episode 480 : Average Reward = -106.52  Number_drops:340 steps:35
# Episode 481 : Average Reward = -106.11  Number_drops:341 steps:42
# Episode 482 : Average Reward = -105.04  Number_drops:342 steps:83
# Episode 483 : Average Reward = -104.77  Number_drops:343 steps:79
# Episode 484 : Average Reward = -105.77  Number_drops:344 steps:152
# Episode 485 : Average Reward = -105.32  Number_drops:345 steps:79
# Episode 486 : Average Reward = -105.93  Number_drops:346 steps:89
# Episode 487 : Average Reward = -105.67  Number_drops:347 steps:14
# Episode 488 : Average Reward = -105.18  Number_drops:348 steps:150
# Episode 489 : Average Reward = -105.33  Number_drops:349 steps:113
# Episode 490 : Average Reward = -103.81  Number_drops:350 steps:13
# Episode 491 : Average Reward = -103.5  Number_drops:351 steps:39
# Episode 492 : Average Reward = -103.75  Number_drops:352 steps:105
# Episode 493 : Average Reward = -102.5  Number_drops:353 steps:75
# Episode 494 : Average Reward = -102.5  Number_drops:353 steps:200
# Episode 495 : Average Reward = -102.08  Number_drops:354 steps:45
# Episode 496 : Average Reward = -102.65  Number_drops:355 steps:133
# Episode 497 : Average Reward = -103.55  Number_drops:356 steps:108
# Episode 498 : Average Reward = -103.56  Number_drops:356 steps:200
# Episode 499 : Average Reward = -104.36  Number_drops:356 steps:199
# Episode 500 : Average Reward = -105.74  Number_drops:356 steps:199
# Episode 501 : Average Reward = -106.28  Number_drops:357 steps:100
# Episode 502 : Average Reward = -106.96  Number_drops:358 steps:178
# Episode 503 : Average Reward = -106.04  Number_drops:359 steps:108
# Episode 504 : Average Reward = -104.75  Number_drops:360 steps:71
# Episode 505 : Average Reward = -105.5  Number_drops:361 steps:114
# Episode 506 : Average Reward = -104.34  Number_drops:362 steps:83
# Episode 507 : Average Reward = -104.39  Number_drops:363 steps:94
# Episode 508 : Average Reward = -104.02  Number_drops:364 steps:33
# Episode 509 : Average Reward = -105.8  Number_drops:364 steps:200
# Episode 510 : Average Reward = -106.34  Number_drops:364 steps:200
# Episode 511 : Average Reward = -108.21  Number_drops:365 steps:196
# Episode 512 : Average Reward = -107.64  Number_drops:366 steps:143
# Episode 513 : Average Reward = -107.97  Number_drops:367 steps:103
# Episode 514 : Average Reward = -108.27  Number_drops:368 steps:50
# Episode 515 : Average Reward = -107.57  Number_drops:369 steps:61
# Episode 516 : Average Reward = -108.21  Number_drops:370 steps:100
# Episode 517 : Average Reward = -106.75  Number_drops:371 steps:53
# Episode 518 : Average Reward = -107.8  Number_drops:372 steps:129
# Episode 519 : Average Reward = -107.15  Number_drops:373 steps:35
# Episode 520 : Average Reward = -109.0  Number_drops:373 steps:199
# Episode 521 : Average Reward = -109.01  Number_drops:373 steps:200
# Episode 522 : Average Reward = -109.01  Number_drops:374 steps:28
# Episode 523 : Average Reward = -107.86  Number_drops:375 steps:84
# Episode 524 : Average Reward = -107.31  Number_drops:376 steps:12
# Episode 525 : Average Reward = -106.42  Number_drops:377 steps:104
# Episode 526 : Average Reward = -107.1  Number_drops:378 steps:154
# Episode 527 : Average Reward = -107.64  Number_drops:379 steps:86
# Episode 528 : Average Reward = -108.91  Number_drops:379 steps:199
# Episode 529 : Average Reward = -108.92  Number_drops:379 steps:200
# Episode 530 : Average Reward = -108.16  Number_drops:380 steps:36
# Episode 531 : Average Reward = -107.92  Number_drops:381 steps:8
# Episode 532 : Average Reward = -108.36  Number_drops:381 steps:200
# Episode 533 : Average Reward = -109.32  Number_drops:381 steps:200
# Episode 534 : Average Reward = -109.47  Number_drops:382 steps:34
# Episode 535 : Average Reward = -109.04  Number_drops:383 steps:156
# Episode 536 : Average Reward = -110.29  Number_drops:383 steps:199
# Episode 537 : Average Reward = -111.34  Number_drops:383 steps:200
# Episode 538 : Average Reward = -110.43  Number_drops:384 steps:109
# Episode 539 : Average Reward = -109.41  Number_drops:385 steps:32
# Episode 540 : Average Reward = -109.81  Number_drops:386 steps:48
# Episode 541 : Average Reward = -110.78  Number_drops:387 steps:129
# Episode 542 : Average Reward = -110.78  Number_drops:387 steps:200
# Episode 543 : Average Reward = -111.53  Number_drops:387 steps:200
# Episode 544 : Average Reward = -112.78  Number_drops:387 steps:200
# Episode 545 : Average Reward = -113.11  Number_drops:388 steps:88
# Episode 546 : Average Reward = -113.11  Number_drops:388 steps:200
# Episode 547 : Average Reward = -111.93  Number_drops:389 steps:82
# Episode 548 : Average Reward = -110.92  Number_drops:390 steps:12
# Episode 549 : Average Reward = -111.36  Number_drops:391 steps:134
# Episode 550 : Average Reward = -112.39  Number_drops:392 steps:161
# Episode 551 : Average Reward = -113.57  Number_drops:393 steps:196
# Episode 552 : Average Reward = -113.57  Number_drops:393 steps:200
# Episode 553 : Average Reward = -114.77  Number_drops:393 steps:200
# Episode 554 : Average Reward = -114.27  Number_drops:394 steps:43
# Episode 555 : Average Reward = -112.6  Number_drops:395 steps:32
# Episode 556 : Average Reward = -112.65  Number_drops:396 steps:142
# Episode 557 : Average Reward = -113.39  Number_drops:397 steps:139
# Episode 558 : Average Reward = -111.73  Number_drops:398 steps:33
# Episode 559 : Average Reward = -111.8  Number_drops:399 steps:33
# Episode 560 : Average Reward = -112.02  Number_drops:400 steps:102
# Episode 561 : Average Reward = -111.4  Number_drops:401 steps:131
# Episode 562 : Average Reward = -112.63  Number_drops:402 steps:148
# Episode 563 : Average Reward = -114.24  Number_drops:402 steps:199
# Episode 564 : Average Reward = -114.4  Number_drops:403 steps:48
# Episode 565 : Average Reward = -115.12  Number_drops:403 steps:200
# Episode 566 : Average Reward = -114.07  Number_drops:404 steps:95
# Episode 567 : Average Reward = -113.74  Number_drops:405 steps:94
# Episode 568 : Average Reward = -114.53  Number_drops:406 steps:104
# Episode 569 : Average Reward = -114.76  Number_drops:406 steps:200
# Episode 570 : Average Reward = -114.64  Number_drops:407 steps:187
# Episode 571 : Average Reward = -114.09  Number_drops:408 steps:28
# Episode 572 : Average Reward = -115.74  Number_drops:409 steps:174
# Episode 573 : Average Reward = -116.69  Number_drops:410 steps:128
# Episode 574 : Average Reward = -118.24  Number_drops:410 steps:199
# Episode 575 : Average Reward = -117.58  Number_drops:411 steps:133
# Episode 576 : Average Reward = -117.84  Number_drops:412 steps:129
# Episode 577 : Average Reward = -116.62  Number_drops:413 steps:78
# Episode 578 : Average Reward = -117.2  Number_drops:414 steps:190
# Episode 579 : Average Reward = -117.61  Number_drops:415 steps:79
# Episode 580 : Average Reward = -117.56  Number_drops:416 steps:30
# Episode 581 : Average Reward = -117.94  Number_drops:417 steps:80
# Episode 582 : Average Reward = -117.59  Number_drops:418 steps:48
# Episode 583 : Average Reward = -118.8  Number_drops:418 steps:200
# Episode 584 : Average Reward = -117.88  Number_drops:419 steps:60
# Episode 585 : Average Reward = -117.21  Number_drops:420 steps:12
# Episode 586 : Average Reward = -117.65  Number_drops:421 steps:133
# Episode 587 : Average Reward = -119.51  Number_drops:421 steps:200
# Episode 588 : Average Reward = -118.53  Number_drops:422 steps:52
# Episode 589 : Average Reward = -117.98  Number_drops:423 steps:58
# Episode 590 : Average Reward = -118.14  Number_drops:424 steps:29
# Episode 591 : Average Reward = -119.16  Number_drops:425 steps:141
# Episode 592 : Average Reward = -118.59  Number_drops:426 steps:48
# Episode 593 : Average Reward = -118.66  Number_drops:427 steps:82
# Episode 594 : Average Reward = -118.37  Number_drops:428 steps:171
# Episode 595 : Average Reward = -118.21  Number_drops:429 steps:29
# Episode 596 : Average Reward = -116.96  Number_drops:430 steps:8
# Episode 597 : Average Reward = -116.94  Number_drops:431 steps:106
# Episode 598 : Average Reward = -116.02  Number_drops:432 steps:108
# Episode 599 : Average Reward = -116.03  Number_drops:432 steps:200
# Episode 600 : Average Reward = -116.04  Number_drops:432 steps:200
# Episode 601 : Average Reward = -116.27  Number_drops:433 steps:123
# Episode 602 : Average Reward = -114.99  Number_drops:434 steps:50
# Episode 603 : Average Reward = -115.37  Number_drops:436 steps:146
# Episode 604 : Average Reward = -116.38  Number_drops:437 steps:172
# Episode 605 : Average Reward = -116.09  Number_drops:438 steps:85
# Episode 606 : Average Reward = -117.26  Number_drops:438 steps:200
# Episode 607 : Average Reward = -118.32  Number_drops:438 steps:200
# Episode 608 : Average Reward = -118.75  Number_drops:439 steps:76
# Episode 609 : Average Reward = -117.99  Number_drops:440 steps:124
# Episode 610 : Average Reward = -116.28  Number_drops:441 steps:29
# Episode 611 : Average Reward = -116.32  Number_drops:441 steps:200
# Episode 612 : Average Reward = -116.16  Number_drops:442 steps:127
# Episode 613 : Average Reward = -117.13  Number_drops:442 steps:200
# Episode 614 : Average Reward = -116.74  Number_drops:443 steps:11
# Episode 615 : Average Reward = -118.12  Number_drops:443 steps:199
# Episode 616 : Average Reward = -119.12  Number_drops:443 steps:200
# Episode 617 : Average Reward = -119.31  Number_drops:444 steps:72
# Episode 618 : Average Reward = -118.51  Number_drops:445 steps:49
# Episode 619 : Average Reward = -120.16  Number_drops:445 steps:200
# Episode 620 : Average Reward = -118.93  Number_drops:446 steps:76
# Episode 621 : Average Reward = -117.34  Number_drops:447 steps:41
# Episode 622 : Average Reward = -119.06  Number_drops:447 steps:200
# Episode 623 : Average Reward = -120.21  Number_drops:447 steps:199
# Episode 624 : Average Reward = -120.61  Number_drops:448 steps:52
# Episode 625 : Average Reward = -121.33  Number_drops:449 steps:176
# Episode 626 : Average Reward = -121.78  Number_drops:449 steps:199
# Episode 627 : Average Reward = -121.92  Number_drops:450 steps:100
# Episode 628 : Average Reward = -120.65  Number_drops:451 steps:72
# Episode 629 : Average Reward = -120.65  Number_drops:451 steps:200
# Episode 630 : Average Reward = -121.37  Number_drops:452 steps:108
# Episode 631 : Average Reward = -121.41  Number_drops:453 steps:12
# Episode 632 : Average Reward = -120.39  Number_drops:454 steps:98
# Episode 633 : Average Reward = -120.39  Number_drops:454 steps:200
# Episode 634 : Average Reward = -122.05  Number_drops:454 steps:200
# Episode 635 : Average Reward = -121.75  Number_drops:455 steps:126
# Episode 636 : Average Reward = -120.02  Number_drops:456 steps:26
# Episode 637 : Average Reward = -120.02  Number_drops:456 steps:200
# Episode 638 : Average Reward = -120.93  Number_drops:456 steps:200
# Episode 639 : Average Reward = -122.61  Number_drops:456 steps:200
# Episode 640 : Average Reward = -122.77  Number_drops:457 steps:64
# Episode 641 : Average Reward = -122.98  Number_drops:458 steps:150
# Episode 642 : Average Reward = -122.66  Number_drops:459 steps:168
# Episode 643 : Average Reward = -121.94  Number_drops:460 steps:128
# Episode 644 : Average Reward = -121.52  Number_drops:461 steps:158
# Episode 645 : Average Reward = -122.47  Number_drops:462 steps:183
# Episode 646 : Average Reward = -121.4  Number_drops:463 steps:93
# Episode 647 : Average Reward = -122.58  Number_drops:463 steps:200
# Episode 648 : Average Reward = -123.16  Number_drops:464 steps:70
# Episode 649 : Average Reward = -122.97  Number_drops:465 steps:115
# Episode 650 : Average Reward = -123.36  Number_drops:465 steps:200
# Episode 651 : Average Reward = -121.93  Number_drops:466 steps:53
# Episode 652 : Average Reward = -121.93  Number_drops:466 steps:200
# Episode 653 : Average Reward = -121.1  Number_drops:467 steps:117
# Episode 654 : Average Reward = -122.67  Number_drops:467 steps:200
# Episode 655 : Average Reward = -122.51  Number_drops:468 steps:16
# Episode 656 : Average Reward = -123.09  Number_drops:468 steps:200
# Episode 657 : Average Reward = -121.87  Number_drops:469 steps:17
# Episode 658 : Average Reward = -123.34  Number_drops:470 steps:180
# Episode 659 : Average Reward = -123.68  Number_drops:471 steps:67
# Episode 660 : Average Reward = -123.59  Number_drops:472 steps:93
# Episode 661 : Average Reward = -123.13  Number_drops:473 steps:85
# Episode 662 : Average Reward = -123.07  Number_drops:474 steps:142
# Episode 663 : Average Reward = -123.07  Number_drops:474 steps:199
# Episode 664 : Average Reward = -124.59  Number_drops:474 steps:200
# Episode 665 : Average Reward = -124.09  Number_drops:475 steps:150
# Episode 666 : Average Reward = -125.14  Number_drops:475 steps:200
# Episode 667 : Average Reward = -126.2  Number_drops:475 steps:200
# Episode 668 : Average Reward = -125.73  Number_drops:476 steps:57
# Episode 669 : Average Reward = -124.31  Number_drops:477 steps:58
# Episode 670 : Average Reward = -123.03  Number_drops:478 steps:59
# Episode 671 : Average Reward = -123.94  Number_drops:479 steps:119
# Episode 672 : Average Reward = -124.2  Number_drops:479 steps:200
# Episode 673 : Average Reward = -124.92  Number_drops:479 steps:200
# Episode 674 : Average Reward = -123.6  Number_drops:480 steps:67
# Episode 675 : Average Reward = -122.46  Number_drops:481 steps:19
# Episode 676 : Average Reward = -122.25  Number_drops:482 steps:108
# Episode 677 : Average Reward = -122.4  Number_drops:483 steps:93
# Episode 678 : Average Reward = -121.75  Number_drops:484 steps:125
# Episode 679 : Average Reward = -122.96  Number_drops:484 steps:200
# Episode 680 : Average Reward = -123.16  Number_drops:485 steps:50
# Episode 681 : Average Reward = -124.36  Number_drops:485 steps:200
# Episode 682 : Average Reward = -124.6  Number_drops:486 steps:72
# Episode 683 : Average Reward = -124.48  Number_drops:487 steps:188
# Episode 684 : Average Reward = -125.15  Number_drops:488 steps:127
# Episode 685 : Average Reward = -125.15  Number_drops:489 steps:12
# Episode 686 : Average Reward = -125.82  Number_drops:489 steps:200
# Episode 687 : Average Reward = -125.82  Number_drops:489 steps:200
# Episode 688 : Average Reward = -125.42  Number_drops:490 steps:12
# Episode 689 : Average Reward = -125.48  Number_drops:491 steps:64
# Episode 690 : Average Reward = -126.71  Number_drops:492 steps:152
# Episode 691 : Average Reward = -127.2  Number_drops:493 steps:190
# Episode 692 : Average Reward = -128.58  Number_drops:494 steps:186
# Episode 693 : Average Reward = -128.51  Number_drops:495 steps:75
# Episode 694 : Average Reward = -128.8  Number_drops:495 steps:200
# Episode 695 : Average Reward = -129.27  Number_drops:496 steps:76
# Episode 696 : Average Reward = -130.83  Number_drops:497 steps:164
# Episode 697 : Average Reward = -130.22  Number_drops:498 steps:45
# Episode 698 : Average Reward = -130.73  Number_drops:499 steps:159
# Episode 699 : Average Reward = -130.45  Number_drops:500 steps:172
# Episode 700 : Average Reward = -129.53  Number_drops:501 steps:108
# Episode 701 : Average Reward = -129.53  Number_drops:502 steps:123
# Episode 702 : Average Reward = -131.03  Number_drops:502 steps:200
# Episode 703 : Average Reward = -131.57  Number_drops:502 steps:200
# Episode 704 : Average Reward = -130.91  Number_drops:503 steps:106
# Episode 705 : Average Reward = -130.56  Number_drops:504 steps:50
# Episode 706 : Average Reward = -130.56  Number_drops:504 steps:200
# Episode 707 : Average Reward = -130.55  Number_drops:504 steps:199
# Episode 708 : Average Reward = -130.61  Number_drops:505 steps:82
# Episode 709 : Average Reward = -129.93  Number_drops:506 steps:56
# Episode 710 : Average Reward = -131.49  Number_drops:507 steps:185
# Episode 711 : Average Reward = -129.78  Number_drops:508 steps:29
# Episode 712 : Average Reward = -130.51  Number_drops:508 steps:200
# ...
# Episode 5263 : Average Reward = -64.89  Number_drops:5061 steps:200
# Episode 5264 : Average Reward = -65.15  Number_drops:5062 steps:59
# Episode 5265 : Average Reward = -63.63  Number_drops:5063 steps:48
# Episode 5266 : Average Reward = -62.1  Number_drops:5064 steps:47
# Episode 5267 : Average Reward = -63.05  Number_drops:5065 steps:172
# Episode 5268 : Average Reward = -62.89  Number_drops:5066 steps:61
# Episode 5269 : Average Reward = -62.74  Number_drops:5067 steps:64
# Episode 5270 : Average Reward = -62.83  Number_drops:5068 steps:35
# Episode 5271 : Average Reward = -62.39  Number_drops:5069 steps:43
# Episode 5272 : Average Reward = -63.49  Number_drops:5069 steps:200
# Episode 5273 : Average Reward = -64.04  Number_drops:5070 steps:78
# Episode 5274 : Average Reward = -63.83  Number_drops:5071 steps:56
# Episode 5275 : Average Reward = -63.7  Number_drops:5072 steps:33
# Episode 5276 : Average Reward = -64.06  Number_drops:5073 steps:124
# Episode 5277 : Average Reward = -64.02  Number_drops:5074 steps:57
# Episode 5278 : Average Reward = -63.63  Number_drops:5075 steps:49
# Episode 5279 : Average Reward = -65.02  Number_drops:5075 steps:200
# Episode 5280 : Average Reward = -64.68  Number_drops:5076 steps:21
# Episode 5281 : Average Reward = -64.3  Number_drops:5077 steps:16
# Episode 5282 : Average Reward = -64.15  Number_drops:5078 steps:75
# Episode 5283 : Average Reward = -64.45  Number_drops:5079 steps:83
# Episode 5284 : Average Reward = -63.33  Number_drops:5080 steps:88
# Episode 5285 : Average Reward = -64.17  Number_drops:5081 steps:183
# Episode 5286 : Average Reward = -63.46  Number_drops:5082 steps:26
# Episode 5287 : Average Reward = -62.72  Number_drops:5083 steps:10
# Episode 5288 : Average Reward = -63.01  Number_drops:5084 steps:69
# Episode 5289 : Average Reward = -62.87  Number_drops:5085 steps:39
# Episode 5290 : Average Reward = -62.47  Number_drops:5086 steps:23
# Episode 5291 : Average Reward = -64.13  Number_drops:5086 steps:200
# Episode 5292 : Average Reward = -63.75  Number_drops:5087 steps:19
# Episode 5293 : Average Reward = -63.2  Number_drops:5088 steps:29
# Episode 5294 : Average Reward = -63.4  Number_drops:5089 steps:80
# Episode 5295 : Average Reward = -63.16  Number_drops:5090 steps:16
# Episode 5296 : Average Reward = -63.5  Number_drops:5091 steps:60
# Episode 5297 : Average Reward = -64.8  Number_drops:5092 steps:150
# Episode 5298 : Average Reward = -65.23  Number_drops:5093 steps:127
# Episode 5299 : Average Reward = -64.24  Number_drops:5094 steps:30
# Episode 5300 : Average Reward = -64.83  Number_drops:5095 steps:71
# Episode 5301 : Average Reward = -64.87  Number_drops:5096 steps:142
# Episode 5302 : Average Reward = -65.11  Number_drops:5097 steps:68
# Episode 5303 : Average Reward = -65.06  Number_drops:5098 steps:54
# Episode 5304 : Average Reward = -65.38  Number_drops:5099 steps:91
# Episode 5305 : Average Reward = -64.92  Number_drops:5100 steps:37
# Episode 5306 : Average Reward = -66.08  Number_drops:5101 steps:128
# Episode 5307 : Average Reward = -67.47  Number_drops:5101 steps:200
# Episode 5308 : Average Reward = -68.22  Number_drops:5102 steps:83
# Episode 5309 : Average Reward = -68.87  Number_drops:5103 steps:129
# Episode 5310 : Average Reward = -68.89  Number_drops:5104 steps:56
# Episode 5311 : Average Reward = -68.68  Number_drops:5105 steps:28
# Episode 5312 : Average Reward = -68.77  Number_drops:5106 steps:101
# Episode 5313 : Average Reward = -70.63  Number_drops:5106 steps:200
# Episode 5314 : Average Reward = -72.36  Number_drops:5106 steps:200
# Episode 5315 : Average Reward = -72.72  Number_drops:5107 steps:79
# Episode 5316 : Average Reward = -74.51  Number_drops:5107 steps:200
# Episode 5317 : Average Reward = -74.76  Number_drops:5108 steps:52
# Episode 5318 : Average Reward = -73.27  Number_drops:5109 steps:45
# Episode 5319 : Average Reward = -74.09  Number_drops:5110 steps:120
# Episode 5320 : Average Reward = -73.43  Number_drops:5111 steps:21
# Episode 5321 : Average Reward = -73.42  Number_drops:5112 steps:21
# Episode 5322 : Average Reward = -73.48  Number_drops:5113 steps:62
# Episode 5323 : Average Reward = -71.91  Number_drops:5114 steps:43
# Episode 5324 : Average Reward = -70.24  Number_drops:5115 steps:32
# Episode 5325 : Average Reward = -71.84  Number_drops:5115 steps:200
# Episode 5326 : Average Reward = -73.29  Number_drops:5115 steps:200
# Episode 5327 : Average Reward = -73.08  Number_drops:5116 steps:37
# Episode 5328 : Average Reward = -72.97  Number_drops:5117 steps:19
# Episode 5329 : Average Reward = -72.81  Number_drops:5118 steps:46
# Episode 5330 : Average Reward = -72.62  Number_drops:5119 steps:16
# Episode 5331 : Average Reward = -72.58  Number_drops:5120 steps:70
# Episode 5332 : Average Reward = -72.79  Number_drops:5121 steps:73
# Episode 5333 : Average Reward = -73.08  Number_drops:5122 steps:58
# Episode 5334 : Average Reward = -74.46  Number_drops:5122 steps:200
# Episode 5335 : Average Reward = -74.16  Number_drops:5123 steps:49
# Episode 5336 : Average Reward = -74.89  Number_drops:5124 steps:95
# Episode 5337 : Average Reward = -75.16  Number_drops:5125 steps:36
# Episode 5338 : Average Reward = -75.84  Number_drops:5126 steps:142
# Episode 5339 : Average Reward = -75.95  Number_drops:5127 steps:29
# Episode 5340 : Average Reward = -76.07  Number_drops:5128 steps:38
# Episode 5341 : Average Reward = -76.9  Number_drops:5129 steps:150
# Episode 5342 : Average Reward = -76.32  Number_drops:5130 steps:32
# Episode 5343 : Average Reward = -75.7  Number_drops:5131 steps:22
# Episode 5344 : Average Reward = -75.97  Number_drops:5132 steps:55
# Episode 5345 : Average Reward = -76.31  Number_drops:5133 steps:104
# Episode 5346 : Average Reward = -76.15  Number_drops:5134 steps:35
# Episode 5347 : Average Reward = -76.55  Number_drops:5135 steps:68
# Episode 5348 : Average Reward = -76.99  Number_drops:5136 steps:72
# Episode 5349 : Average Reward = -76.31  Number_drops:5137 steps:37
# Episode 5350 : Average Reward = -76.86  Number_drops:5138 steps:78
# Episode 5351 : Average Reward = -77.13  Number_drops:5139 steps:61
# Episode 5352 : Average Reward = -77.52  Number_drops:5140 steps:88
# Episode 5353 : Average Reward = -78.16  Number_drops:5141 steps:79
# Episode 5354 : Average Reward = -77.61  Number_drops:5142 steps:31
# Episode 5355 : Average Reward = -77.98  Number_drops:5143 steps:49
# Episode 5356 : Average Reward = -78.28  Number_drops:5144 steps:47
# Episode 5357 : Average Reward = -78.25  Number_drops:5145 steps:9
# Episode 5358 : Average Reward = -78.48  Number_drops:5146 steps:88
# Episode 5359 : Average Reward = -77.53  Number_drops:5147 steps:105
# Episode 5360 : Average Reward = -77.69  Number_drops:5148 steps:29
# Episode 5361 : Average Reward = -77.76  Number_drops:5149 steps:38
# Episode 5362 : Average Reward = -77.3  Number_drops:5150 steps:12
# Episode 5363 : Average Reward = -75.52  Number_drops:5151 steps:22
# Episode 5364 : Average Reward = -75.51  Number_drops:5152 steps:58
# Episode 5365 : Average Reward = -75.5  Number_drops:5153 steps:47
# Episode 5366 : Average Reward = -75.35  Number_drops:5154 steps:32
# Episode 5367 : Average Reward = -74.12  Number_drops:5155 steps:49
# Episode 5368 : Average Reward = -73.94  Number_drops:5156 steps:43
# Episode 5369 : Average Reward = -73.69  Number_drops:5157 steps:39
# Episode 5370 : Average Reward = -73.44  Number_drops:5158 steps:10
# Episode 5371 : Average Reward = -73.27  Number_drops:5159 steps:26
# Episode 5372 : Average Reward = -72.84  Number_drops:5160 steps:157
# Episode 5373 : Average Reward = -73.0  Number_drops:5161 steps:94
# Episode 5374 : Average Reward = -72.67  Number_drops:5162 steps:23
# Episode 5375 : Average Reward = -73.3  Number_drops:5163 steps:96
# Episode 5376 : Average Reward = -72.88  Number_drops:5164 steps:82
# Episode 5377 : Average Reward = -72.77  Number_drops:5165 steps:46
# Episode 5378 : Average Reward = -72.95  Number_drops:5166 steps:67
# Episode 5379 : Average Reward = -72.95  Number_drops:5166 steps:200
# Episode 5380 : Average Reward = -74.74  Number_drops:5166 steps:200
# Episode 5381 : Average Reward = -75.33  Number_drops:5167 steps:75
# Episode 5382 : Average Reward = -75.36  Number_drops:5168 steps:78
# Episode 5383 : Average Reward = -74.75  Number_drops:5169 steps:22
# Episode 5384 : Average Reward = -75.87  Number_drops:5169 steps:200
# Episode 5385 : Average Reward = -74.88  Number_drops:5170 steps:84
# Episode 5386 : Average Reward = -74.77  Number_drops:5171 steps:15
# Episode 5387 : Average Reward = -74.77  Number_drops:5172 steps:10
# Episode 5388 : Average Reward = -75.17  Number_drops:5173 steps:109
# Episode 5389 : Average Reward = -75.16  Number_drops:5174 steps:38
# Episode 5390 : Average Reward = -75.17  Number_drops:5175 steps:24
# Episode 5391 : Average Reward = -74.01  Number_drops:5176 steps:84
# Episode 5392 : Average Reward = -74.25  Number_drops:5177 steps:43
# Episode 5393 : Average Reward = -75.96  Number_drops:5177 steps:200
# Episode 5394 : Average Reward = -75.69  Number_drops:5178 steps:53
# Episode 5395 : Average Reward = -76.02  Number_drops:5179 steps:49
# Episode 5396 : Average Reward = -76.22  Number_drops:5180 steps:80
# Episode 5397 : Average Reward = -76.7  Number_drops:5181 steps:198
# Episode 5398 : Average Reward = -76.27  Number_drops:5182 steps:84
# Episode 5399 : Average Reward = -77.97  Number_drops:5182 steps:200
# Episode 5400 : Average Reward = -77.5  Number_drops:5183 steps:24
# Episode 5401 : Average Reward = -76.48  Number_drops:5184 steps:40
# Episode 5402 : Average Reward = -76.12  Number_drops:5185 steps:32
# Episode 5403 : Average Reward = -76.39  Number_drops:5186 steps:81
# Episode 5404 : Average Reward = -75.76  Number_drops:5187 steps:28
# Episode 5405 : Average Reward = -75.65  Number_drops:5188 steps:26
# Episode 5406 : Average Reward = -74.74  Number_drops:5189 steps:37
# Episode 5407 : Average Reward = -73.29  Number_drops:5190 steps:55
# Episode 5408 : Average Reward = -74.25  Number_drops:5191 steps:179
# Episode 5409 : Average Reward = -73.64  Number_drops:5192 steps:68
# Episode 5410 : Average Reward = -73.65  Number_drops:5193 steps:57
# Episode 5411 : Average Reward = -73.93  Number_drops:5194 steps:56
# Episode 5412 : Average Reward = -73.33  Number_drops:5195 steps:41
# Episode 5413 : Average Reward = -71.5  Number_drops:5196 steps:17
# Episode 5414 : Average Reward = -70.04  Number_drops:5197 steps:54
# Episode 5415 : Average Reward = -69.67  Number_drops:5198 steps:42
# Episode 5416 : Average Reward = -68.27  Number_drops:5199 steps:60
# Episode 5417 : Average Reward = -68.73  Number_drops:5200 steps:98
# Episode 5418 : Average Reward = -68.82  Number_drops:5201 steps:54
# Episode 5419 : Average Reward = -68.52  Number_drops:5202 steps:90
# Episode 5420 : Average Reward = -68.98  Number_drops:5203 steps:67
# Episode 5421 : Average Reward = -69.09  Number_drops:5204 steps:32
# Episode 5422 : Average Reward = -68.95  Number_drops:5205 steps:48
# Episode 5423 : Average Reward = -68.7  Number_drops:5206 steps:18
# Episode 5424 : Average Reward = -68.65  Number_drops:5207 steps:27
# Episode 5425 : Average Reward = -67.16  Number_drops:5208 steps:51
# Episode 5426 : Average Reward = -65.49  Number_drops:5209 steps:33
# Episode 5427 : Average Reward = -65.24  Number_drops:5210 steps:12
# Episode 5428 : Average Reward = -65.22  Number_drops:5211 steps:17
# Episode 5429 : Average Reward = -64.98  Number_drops:5212 steps:22
# Episode 5430 : Average Reward = -65.34  Number_drops:5213 steps:52
# Episode 5431 : Average Reward = -64.85  Number_drops:5214 steps:21
# Episode 5432 : Average Reward = -64.91  Number_drops:5215 steps:79
# Episode 5433 : Average Reward = -65.23  Number_drops:5216 steps:90
# Episode 5434 : Average Reward = -63.65  Number_drops:5217 steps:42
# Episode 5435 : Average Reward = -65.16  Number_drops:5217 steps:200
# Episode 5436 : Average Reward = -64.64  Number_drops:5218 steps:43
# Episode 5437 : Average Reward = -64.97  Number_drops:5219 steps:69
# Episode 5438 : Average Reward = -63.9  Number_drops:5220 steps:35
# Episode 5439 : Average Reward = -64.54  Number_drops:5221 steps:93
# Episode 5440 : Average Reward = -64.34  Number_drops:5222 steps:18
# Episode 5441 : Average Reward = -63.0  Number_drops:5223 steps:16
# Episode 5442 : Average Reward = -62.9  Number_drops:5224 steps:22
# Episode 5443 : Average Reward = -62.9  Number_drops:5225 steps:22
# Episode 5444 : Average Reward = -63.93  Number_drops:5226 steps:158
# Episode 5445 : Average Reward = -63.27  Number_drops:5227 steps:38
# Episode 5446 : Average Reward = -63.14  Number_drops:5228 steps:22
# Episode 5447 : Average Reward = -64.42  Number_drops:5229 steps:196
# Episode 5448 : Average Reward = -63.96  Number_drops:5230 steps:26
# Episode 5449 : Average Reward = -65.32  Number_drops:5231 steps:173
# Episode 5450 : Average Reward = -65.24  Number_drops:5232 steps:70
# Episode 5451 : Average Reward = -65.28  Number_drops:5233 steps:65
# Episode 5452 : Average Reward = -64.98  Number_drops:5234 steps:58
# Episode 5453 : Average Reward = -64.3  Number_drops:5235 steps:11
# Episode 5454 : Average Reward = -64.46  Number_drops:5236 steps:47
# Episode 5455 : Average Reward = -65.97  Number_drops:5236 steps:200
# Episode 5456 : Average Reward = -65.65  Number_drops:5237 steps:15
# Episode 5457 : Average Reward = -65.78  Number_drops:5238 steps:22
# Episode 5458 : Average Reward = -65.26  Number_drops:5239 steps:36
# Episode 5459 : Average Reward = -65.08  Number_drops:5240 steps:87
# Episode 5460 : Average Reward = -65.57  Number_drops:5241 steps:78
# Episode 5461 : Average Reward = -66.2  Number_drops:5242 steps:101
# Episode 5462 : Average Reward = -66.17  Number_drops:5243 steps:9
# Episode 5463 : Average Reward = -66.91  Number_drops:5244 steps:96
# Episode 5464 : Average Reward = -66.88  Number_drops:5245 steps:55
# Episode 5465 : Average Reward = -68.41  Number_drops:5245 steps:200
# Episode 5466 : Average Reward = -68.26  Number_drops:5246 steps:17
# Episode 5467 : Average Reward = -68.54  Number_drops:5247 steps:77
# Episode 5468 : Average Reward = -68.47  Number_drops:5248 steps:36
# Episode 5469 : Average Reward = -68.51  Number_drops:5249 steps:43
# Episode 5470 : Average Reward = -69.29  Number_drops:5250 steps:88
# Episode 5471 : Average Reward = -69.28  Number_drops:5251 steps:25
# Episode 5472 : Average Reward = -68.38  Number_drops:5252 steps:67
# Episode 5473 : Average Reward = -67.59  Number_drops:5253 steps:15
# Episode 5474 : Average Reward = -67.8  Number_drops:5254 steps:44
# Episode 5475 : Average Reward = -67.45  Number_drops:5255 steps:61
# Episode 5476 : Average Reward = -68.63  Number_drops:5255 steps:200
# Episode 5477 : Average Reward = -69.24  Number_drops:5256 steps:107
# Episode 5478 : Average Reward = -69.6  Number_drops:5257 steps:103
# Episode 5479 : Average Reward = -69.6  Number_drops:5257 steps:200
# Episode 5480 : Average Reward = -69.55  Number_drops:5258 steps:195
# Episode 5481 : Average Reward = -69.67  Number_drops:5259 steps:87
# Episode 5482 : Average Reward = -69.23  Number_drops:5260 steps:34
# Episode 5483 : Average Reward = -69.77  Number_drops:5261 steps:76
# Episode 5484 : Average Reward = -68.12  Number_drops:5262 steps:35
# Episode 5485 : Average Reward = -67.79  Number_drops:5263 steps:51
# Episode 5486 : Average Reward = -68.35  Number_drops:5264 steps:71
# Episode 5487 : Average Reward = -69.16  Number_drops:5265 steps:91
# Episode 5488 : Average Reward = -68.31  Number_drops:5266 steps:24
# Episode 5489 : Average Reward = -68.04  Number_drops:5267 steps:11
# Episode 5490 : Average Reward = -68.38  Number_drops:5268 steps:58
# Episode 5491 : Average Reward = -69.34  Number_drops:5269 steps:180
# Episode 5492 : Average Reward = -69.25  Number_drops:5270 steps:34
# Episode 5493 : Average Reward = -67.49  Number_drops:5271 steps:24
# Episode 5494 : Average Reward = -67.67  Number_drops:5272 steps:71
# Episode 5495 : Average Reward = -69.18  Number_drops:5272 steps:200
# Episode 5496 : Average Reward = -68.52  Number_drops:5273 steps:14
# Episode 5497 : Average Reward = -66.85  Number_drops:5274 steps:31
# Episode 5498 : Average Reward = -67.0  Number_drops:5275 steps:99
# Episode 5499 : Average Reward = -65.37  Number_drops:5276 steps:37
# Episode 5500 : Average Reward = -65.52  Number_drops:5277 steps:39

# %%
import matplotlib.pyplot as plt
window = 100
avg_rews_smdp = [np.average(rewards_smdp[i:i+window])
                 for i in range(len(rewards_smdp)-window)]
plt.plot(avg_rews_smdp, label='Model Score')
plt.xlabel('Episodes')
plt.ylabel('score averaged over previous 100 runs')
plt.title('SMDP over options with Q-learning Option policies')
plt.legend()
plt.axhline(y=8, color='red', linestyle='--')

# %%
state_array = np.array(state_counts, dtype="int")
num_substates = 20
fig, axes = plt.subplots(4, 5, figsize=(15, 12))

for substate in range(num_substates):
    substate_counts_1d = state_array[:, substate]
    substate_counts_2d = substate_counts_1d.reshape((5, 5))

    ax = axes[substate // 5, substate % 5]

    sns.heatmap(substate_counts_2d, annot=True,
                cmap='coolwarm', fmt='d', ax=ax)

    ax.set_title(
        f'(Passenger,Drop location)= {substate//nDrops,substate%nDrops}')

    ax.set_xlabel('Column')
    ax.set_ylabel('Row')

fig.suptitle('State Counts Heatmaps for Each Substate', fontsize=16)
plt.tight_layout()
plt.show()

# %%
env = gym.make("Taxi-v3", render_mode="human")
state, _ = env.reset()
done = False
in_taxi = False
q_values_SMDP = Q_smdp
total_reward = 0
x, y, pas, drop = env.decode(state)
print(f"Running for substate {nDrops*pas+drop}")
while not done:
    x, y, pas, drop = env.decode(state)
    subState = nDrops*pas+drop
    action = np.argmax(q_values_SMDP[5*x+y, subState])
    optdone = False
    move = 0
    prev = state
    while (optdone == False) and not done:
        x, y, pas, drop = env.decode(state)
        optdone = False
        if not optdone and not done:
            optact = action
            for j in range(2):
                taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(
                    state)
                next_state, reward, done, truncated, _ = env.step(optact)
                steps += 1
                taxi_row_new, taxi_col_new, passenger_location_id, drop_location_id = env.decode(
                    next_state)
                total_reward += reward
                reward_bar = gamma*reward_bar + reward
                reward_surr = reward
                locations = {0: [0, 0], 1: [0, 4], 2: [4, 0],
                             3: [4, 3], 4: [taxi_row, taxi_col]}
                loc = locations[passenger_location_id]
                taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(
                    next_state)
                if loc[0] == taxi_row and loc[1] == taxi_col and drop_location_id != passenger_location_id and not in_taxi:
                    optact = 4
                    in_taxi = True
                    optdone = True
                    next_state, reward, done, truncated, _ = env.step(optact)
                    total_reward += reward
                    break
                if goal[drop_location_id][0] == taxi_row and goal[drop_location_id][1] == taxi_col and passenger_location_id == 4:
                    optact = 5
                    optdone = True
                    number_drops += 1
                    next_state, reward, done, truncated, _ = env.step(optact)
                    total_reward += reward
                    break
                state = next_state
            optdone = True
print(f"Total Reward for this substate = {total_reward}")
# Out:
# Running for substate 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-152-2176c950ae93> in <module>
#      22                 taxi_row, taxi_col, passenger_location_id, drop_location_id = env.decode(
#      23                     state)
# ---> 24                 next_state, reward, done, truncated, _ = env.step(optact)
#      25                 steps += 1
#      26                 taxi_row_new, taxi_col_new, passenger_location_id, drop_location_id = env.decode(
#
# ~/miniconda3/envs/YOLOP_lane/lib/python3.7/site-packages/gym/wrappers/time_limit.py in step(self, action)
#      48
#      49         """
# ---> 50         observation, reward, terminated, truncated, info = self.env.step(action)
#      51         self._elapsed_steps += 1
#      52
#
# ~/miniconda3/envs/YOLOP_lane/lib/python3.7/site-packages/gym/wrappers/order_enforcing.py in step(self, action)
#      35         if not self._has_reset:
#      36             raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37         return self.env.step(action)
#      38
#      39     def reset(self, **kwargs):
#
# ~/miniconda3/envs/YOLOP_lane/lib/python3.7/site-packages/gym/wrappers/env_checker.py in step(self, action)
#      37             return env_step_passive_checker(self.env, action)
#      38         else:
# ---> 39             return self.env.step(action)
#      40
#      41     def reset(self, **kwargs):
#
# ~/miniconda3/envs/YOLOP_lane/lib/python3.7/site-packages/gym/envs/toy_text/taxi.py in step(self, a)
#     260
#     261         if self.render_mode == "human":
# --> 262             self.render()
#     263         return (int(s), r, t, False, {"prob": p, "action_mask": self.action_mask(s)})
#     264
#
# ~/miniconda3/envs/YOLOP_lane/lib/python3.7/site-packages/gym/envs/toy_text/taxi.py in render(self)
#     288             return self._render_text()
#     289         else:  # self.render_mode in {"human", "rgb_array"}:
# --> 290             return self._render_gui(self.render_mode)
#     291
#     292     def _render_gui(self, mode):
#
# ~/miniconda3/envs/YOLOP_lane/lib/python3.7/site-packages/gym/envs/toy_text/taxi.py in _render_gui(self, mode)
#     414         if mode == "human":
#     415             pygame.display.update()
# --> 416             self.clock.tick(self.metadata["render_fps"])
#     417         elif mode == "rgb_array":
#     418             return np.transpose(
#
# KeyboardInterrupt:

# %%
import seaborn as sns
substates = 20
option_names = {
    0: "↑ 2",
    1: "↓ 2",
    2: "→ 2",
    3: "← 2"
}
num_substates = 20

fig, axes = plt.subplots(4, 5, figsize=(15, 12))

for substate in range(num_substates):
    learned_options = np.argmax(Q_smdp[:, substate], axis=1)
    learned_options_names = np.vectorize(option_names.get)(learned_options)
    learned_options_2d = learned_options.reshape((5, 5))
    annot_text = learned_options_names.reshape((5, 5))
    ax = axes[substate // 5, substate % 5]
    sns.heatmap(learned_options_2d, annot=annot_text,
                cmap='viridis', fmt='', ax=ax, cbar=False)
    ax.set_title(
        f'(Passenger,Drop location)= {substate//nDrops,substate%nDrops}')
    ax.set_xlabel('Column')
    ax.set_ylabel('Row')

fig.suptitle('Learned Options Heatmaps for Each Substate', fontsize=16)
plt.tight_layout()
plt.show()
